# %%
from parachorpy import parachor as IFT
import numpy as np, pandas as pd, csv, os
from ctREFPROP.ctREFPROP import REFPROPFunctionLibrary
import matplotlib.pyplot as plt
from CNT_BINARY import SHLMixture, SCLMixture
from math import isnan

# %%
if __name__ == '__main__':
    
    json_files  = ["Mulero_2012.json"]
    model       = IFT.InterfacialTension(json_files)
    model.ctREFPROP_init('~/Software/REFPROP_BETA/REFPROP-cmake/build', gerg_enable=1)

    MIXTURE   = "CO2;Nitrogen"
    z         = [0.95, 0.05]
    T_list    = np.arange(220, 300, 1).tolist()
    kij       = 0.0
    phi_ij    = 1.0
        
    
results_all = []

for T in T_list:
    result = model.TP_DIAGRAM(MIXTURE, z, T, verbose=False)

    # tiny tolerance to avoid numerical issues exactly at phase limits
    tol_frac = 0.000005
    P_bub = result['bubble']['P_bar']
    P_dew = result['dew']['P_bar']

    # evaluate at both endpoints (tweaked by tol)
    PRESSURES = np.array([
        P_bub * (1.0 - tol_frac),  # bubble-side
        P_dew * (1.0 + tol_frac),  # dew-side
    ])

    print(f"T={T:.2f} K | evaluating at P_bubble={PRESSURES[0]:.6f} bar, P_dew={PRESSURES[1]:.6f} bar")

    Pbar, gamma_Parachor, gamma_WSD, x, y, rhol, rhov, mml, mmv = \
        model.gamma_TP(MIXTURE, z, T, PRESSURES, kij, phi_ij)

    
    # per-temperature envelope snapshot
    envelope = {
        "bubble": {
            "P_bar": round(P_bub, 6),
            "x": [round(v, 6) for v in result['bubble']['x']],
            "y": [round(v, 6) for v in result['bubble']['y']],
        },
        "dew": {
            "P_bar": round(P_dew, 6),
            "x": [round(v, 6) for v in result['dew']['x']],
            "y": [round(v, 6) for v in result['dew']['y']],
        },
        "Tc_K": round(result["Tc"], 4),
    }

    # build labeled rows for the two pressures
    samples = []
    for P, s1, s2, xl, yv, ml, mv, rhol_i, rhog_i in zip(Pbar, gamma_Parachor, gamma_WSD, x, y, mml, mmv, rhol, rhov):
        # decide which endpoint this is closest to
        point_type = "bubble" if abs(P - P_bub) <= abs(P - P_dew) else "dew"

        samples.append({
            "point_type": point_type,                      # "bubble" or "dew"
            "T_K": round(T, 4),
            "P_bar": round(P, 6),
            "gamma_Parachor_mN_m": round(s1, 8),
            "gamma_WSD_mN_m": round(s2, 8),
            "x": [round(v, 6) for v in xl],
            "y": [round(v, 6) for v in yv],
            "M_liq_kg_per_mol": round(ml, 8),
            "M_vap_kg_per_mol": round(mv, 8),
            "rho_liq_kg_per_m3": round(rhol_i, 6),
            "rho_vap_kg_per_m3": round(rhog_i, 6),
        })

    # one record per temperature with both labeled points
    results_all.append({
        "mixture": MIXTURE,
        "z": z,
        "kij": kij,
        "phi_ij": phi_ij,
        "T_K": round(T, 4),
        "envelope": envelope,   # bubble/dew data & Tc for this T
        "samples": samples,     # two rows: bubble & dew
    })

    # (optional) your printout
    print("\n--- Results ---")
    print(f"Temperature           : {T:.4f} K")
    print(f"Critical Temperature  : {envelope['Tc_K']:.4f} K")
    print("Pbar:", [round(float(v), 6) for v in Pbar[:2]])
    print("gamma_Parachor_mN_m:", [round(float(v), 8) for v in gamma_Parachor[:2]])
    print("gamma_WSD_mN_m:", [round(float(v), 8) for v in gamma_WSD[:2]])
    print("x:", [[round(float(e), 6) for e in arr] for arr in x[:2]])
    print("y:", [[round(float(e), 6) for e in arr] for arr in y[:2]])
    print("M_liq:", [round(float(v), 8) for v in mml[:2]])
    print("M_vap:", [round(float(v), 8) for v in mmv[:2]])
    print("rho_liq:", [round(float(v), 6) for v in rhol[:2]])
    print("rho_vap:", [round(float(v), 6) for v in rhov[:2]])
    print("--- End ---\n")
# Out:
# REFPROP version = 10.0.2.01
# GERG-2008 model = Enabled
# T=220.00 K | evaluating at P_bubble=41.656020 bar, P_dew=6.341958 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 220.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [41.65602, 6.341958]
# gamma_Parachor_mN_m: [12.24535835, 0.0]
# gamma_WSD_mN_m: [15.756672, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.191332, 0.808668], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [31.07396226, 43.209695]
# rho_liq: [1173.920303, -9999990.0]
# rho_vap: [80.492721, -9999990.0]
# --- End ---
#
# T=221.00 K | evaluating at P_bubble=41.641464 bar, P_dew=6.613531 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 221.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [41.641464, 6.613531]
# gamma_Parachor_mN_m: [12.09257329, 0.0]
# gamma_WSD_mN_m: [15.52295807, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.198337, 0.801663], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [31.1860179, 43.209695]
# rho_liq: [1170.327419, -9999990.0]
# rho_vap: [80.450567, -9999990.0]
# --- End ---
#
# T=222.00 K | evaluating at P_bubble=41.641696 bar, P_dew=6.893810 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 222.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [41.641696, 6.89381]
# gamma_Parachor_mN_m: [11.93859974, 0.0]
# gamma_WSD_mN_m: [15.29008071, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.205465, 0.794535], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [31.30003905, 43.209695]
# rho_liq: [1166.720105, -9999990.0]
# rho_vap: [80.450418, -9999990.0]
# --- End ---
#
# T=223.00 K | evaluating at P_bubble=41.656574 bar, P_dew=7.182972 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 223.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [41.656574, 7.182972]
# gamma_Parachor_mN_m: [11.78353163, 0.0]
# gamma_WSD_mN_m: [15.05804806, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.212712, 0.787288], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [31.41596125, 43.209695]
# rho_liq: [1163.097968, -9999990.0]
# rho_vap: [80.491674, -9999990.0]
# --- End ---
#
# T=224.00 K | evaluating at P_bubble=41.685972 bar, P_dew=7.481199 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 224.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [41.685972, 7.481199]
# gamma_Parachor_mN_m: [11.6274587, 0.0]
# gamma_WSD_mN_m: [14.82686846, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.220073, 0.779927], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [31.53371622, 43.209695]
# rho_liq: [1159.460604, -9999990.0]
# rho_vap: [80.5738, -9999990.0]
# --- End ---
#
# T=225.00 K | evaluating at P_bubble=41.729780 bar, P_dew=7.788671 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 225.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [41.72978, 7.788671]
# gamma_Parachor_mN_m: [11.47046623, 0.0]
# gamma_WSD_mN_m: [14.59655038, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.227545, 0.772455], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [31.65323157, 43.209695]
# rho_liq: [1155.807598, -9999990.0]
# rho_vap: [80.696326, -9999990.0]
# --- End ---
#
# T=226.00 K | evaluating at P_bubble=41.787901 bar, P_dew=8.105570 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 226.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [41.787901, 8.10557]
# gamma_Parachor_mN_m: [11.31263626, 0.0]
# gamma_WSD_mN_m: [14.36710253, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.235122, 0.764878], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [31.77443173, 43.209695]
# rho_liq: [1152.138529, -9999990.0]
# rho_vap: [80.85883, -9999990.0]
# --- End ---
#
# T=227.00 K | evaluating at P_bubble=41.860235 bar, P_dew=8.432082 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 227.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [41.860235, 8.432082]
# gamma_Parachor_mN_m: [11.15404835, 0.0]
# gamma_WSD_mN_m: [14.13853377, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.242799, 0.757201], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [31.89723843, 43.209695]
# rho_liq: [1148.452959, -9999990.0]
# rho_vap: [81.060922, -9999990.0]
# --- End ---
#
# T=228.00 K | evaluating at P_bubble=41.946746 bar, P_dew=8.768392 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 228.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [41.946746, 8.768392]
# gamma_Parachor_mN_m: [10.99477464, 0.0]
# gamma_WSD_mN_m: [13.91085317, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.250572, 0.749428], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [32.02156697, 43.209695]
# rho_liq: [1144.750452, -9999990.0]
# rho_vap: [81.302354, -9999990.0]
# --- End ---
#
# T=229.00 K | evaluating at P_bubble=42.047353 bar, P_dew=9.114687 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 229.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [42.047353, 9.114687]
# gamma_Parachor_mN_m: [10.83488916, 0.0]
# gamma_WSD_mN_m: [13.68406998, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.258434, 0.741566], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [32.14733339, 43.209695]
# rho_liq: [1141.030548, -9999990.0]
# rho_vap: [81.582818, -9999990.0]
# --- End ---
#
# T=230.00 K | evaluating at P_bubble=42.162010 bar, P_dew=9.471156 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 230.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [42.16201, 9.471156]
# gamma_Parachor_mN_m: [10.67446096, 0.0]
# gamma_WSD_mN_m: [13.45819368, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.266381, 0.733619], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [32.27444917, 43.209695]
# rho_liq: [1137.292779, -9999990.0]
# rho_vap: [81.902102, -9999990.0]
# --- End ---
#
# T=231.00 K | evaluating at P_bubble=42.290674 bar, P_dew=9.837990 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 231.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [42.290674, 9.83799]
# gamma_Parachor_mN_m: [10.51355702, 0.0]
# gamma_WSD_mN_m: [13.23323392, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.274406, 0.725594], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [32.40282374, 43.209695]
# rho_liq: [1133.536664, -9999990.0]
# rho_vap: [82.260021, -9999990.0]
# --- End ---
#
# T=232.00 K | evaluating at P_bubble=42.433274 bar, P_dew=10.215381 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 232.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [42.433274, 10.215381]
# gamma_Parachor_mN_m: [10.35224493, 0.0]
# gamma_WSD_mN_m: [13.00920059, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.282504, 0.717496], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [32.53236719, 43.209695]
# rho_liq: [1129.761698, -9999990.0]
# rho_vap: [82.656362, -9999990.0]
# --- End ---
#
# T=233.00 K | evaluating at P_bubble=42.589876 bar, P_dew=10.603522 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 233.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [42.589876, 10.603522]
# gamma_Parachor_mN_m: [10.19058074, 0.0]
# gamma_WSD_mN_m: [12.78610385, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.29067, 0.70933], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [32.6629785, 43.209695]
# rho_liq: [1125.967398, -9999990.0]
# rho_vap: [83.091174, -9999990.0]
# --- End ---
#
# T=234.00 K | evaluating at P_bubble=42.760416 bar, P_dew=11.002610 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 234.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [42.760416, 11.00261]
# gamma_Parachor_mN_m: [10.02862814, 0.0]
# gamma_WSD_mN_m: [12.56395404, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.298896, 0.701104], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [32.79456412, 43.209695]
# rho_liq: [1122.153229, -9999990.0]
# rho_vap: [83.56431, -9999990.0]
# --- End ---
#
# T=235.00 K | evaluating at P_bubble=42.944887 bar, P_dew=11.412841 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 235.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [42.944887, 11.412841]
# gamma_Parachor_mN_m: [9.86644597, 0.0]
# gamma_WSD_mN_m: [12.34276175, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.307177, 0.692823], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [32.9270263, 43.209695]
# rho_liq: [1118.318653, -9999990.0]
# rho_vap: [84.075727, -9999990.0]
# --- End ---
#
# T=236.00 K | evaluating at P_bubble=43.143288 bar, P_dew=11.834416 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 236.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [43.143288, 11.834416]
# gamma_Parachor_mN_m: [9.704091, 11.96908884]
# gamma_WSD_mN_m: [12.12253784, 12.00895778]
# x: [[1.0, 0.0], [0.999016, 0.000984]]
# y: [[0.315506, 0.684494], [0.949996, 0.050004]]
# M_liq: [44.0095, 43.99375281]
# M_vap: [33.0602657, 43.20963152]
# rho_liq: [1114.463117, 1104.282042]
# rho_vap: [84.625426, 30.185119]
# --- End ---
#
# T=237.00 K | evaluating at P_bubble=43.355623 bar, P_dew=12.267534 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 237.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [43.355623, 12.267534]
# gamma_Parachor_mN_m: [9.54161945, 0.0]
# gamma_WSD_mN_m: [11.90329351, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.323878, 0.676122], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [33.19418313, 43.209695]
# rho_liq: [1110.586051, -9999990.0]
# rho_vap: [85.213413, -9999990.0]
# --- End ---
#
# T=238.00 K | evaluating at P_bubble=43.581902 bar, P_dew=12.712400 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 238.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [43.581902, 12.7124]
# gamma_Parachor_mN_m: [9.37908478, 0.0]
# gamma_WSD_mN_m: [11.68504013, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.332286, 0.667714], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [33.32867737, 43.209695]
# rho_liq: [1106.686867, -9999990.0]
# rho_vap: [85.83975, -9999990.0]
# --- End ---
#
# T=239.00 K | evaluating at P_bubble=43.822140 bar, P_dew=13.169218 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 239.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [43.82214, 13.169218]
# gamma_Parachor_mN_m: [9.21654017, 0.0]
# gamma_WSD_mN_m: [11.46778947, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.340724, 0.659276], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [33.46364787, 43.209695]
# rho_liq: [1102.76496, -9999990.0]
# rho_vap: [86.504508, -9999990.0]
# --- End ---
#
# T=240.00 K | evaluating at P_bubble=44.076355 bar, P_dew=13.638195 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 240.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [44.076355, 13.638195]
# gamma_Parachor_mN_m: [9.05403779, 0.0]
# gamma_WSD_mN_m: [11.25155361, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.349185, 0.650815], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [33.59899415, 43.209695]
# rho_liq: [1098.819703, -9999990.0]
# rho_vap: [87.207773, -9999990.0]
# --- End ---
#
# T=241.00 K | evaluating at P_bubble=44.344570 bar, P_dew=14.119542 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 241.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [44.34457, 14.119542]
# gamma_Parachor_mN_m: [8.89162725, 0.0]
# gamma_WSD_mN_m: [11.03634485, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.357663, 0.642337], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [33.73461425, 43.209695]
# rho_liq: [1094.850452, -9999990.0]
# rho_vap: [87.949693, -9999990.0]
# --- End ---
#
# T=242.00 K | evaluating at P_bubble=44.626766 bar, P_dew=14.613469 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 242.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [44.626766, 14.613469]
# gamma_Parachor_mN_m: [8.72936302, 0.0]
# gamma_WSD_mN_m: [10.82217608, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.366153, 0.633847], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [33.87041412, 43.209695]
# rho_liq: [1090.856526, -9999990.0]
# rho_vap: [88.730285, -9999990.0]
# --- End ---
#
# T=243.00 K | evaluating at P_bubble=44.923067 bar, P_dew=15.120191 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 243.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [44.923067, 15.120191]
# gamma_Parachor_mN_m: [8.56728775, 0.0]
# gamma_WSD_mN_m: [10.60906053, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.374647, 0.625353], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [34.0062843, 43.209695]
# rho_liq: [1086.837265, -9999990.0]
# rho_vap: [89.549886, -9999990.0]
# --- End ---
#
# T=244.00 K | evaluating at P_bubble=45.233454 bar, P_dew=15.639925 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 244.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [45.233454, 15.639925]
# gamma_Parachor_mN_m: [8.40545285, 0.0]
# gamma_WSD_mN_m: [10.39701169, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.383139, 0.616861], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [34.14213045, 43.209695]
# rho_liq: [1082.791941, -9999990.0]
# rho_vap: [90.408583, -9999990.0]
# --- End ---
#
# T=245.00 K | evaluating at P_bubble=45.557961 bar, P_dew=16.172889 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 245.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [45.557961, 16.172889]
# gamma_Parachor_mN_m: [8.24390664, 0.0]
# gamma_WSD_mN_m: [10.18604364, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.391624, 0.608376], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [34.27785504, 43.209695]
# rho_liq: [1078.719819, -9999990.0]
# rho_vap: [91.306552, -9999990.0]
# --- End ---
#
# T=246.00 K | evaluating at P_bubble=45.896621 bar, P_dew=16.719306 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 246.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [45.896621, 16.719306]
# gamma_Parachor_mN_m: [8.08269673, 0.0]
# gamma_WSD_mN_m: [9.97617091, 0.0]
# x: [[1.0, 0.0], [0.95, 0.05]]
# y: [[0.400095, 0.599905], [0.95, 0.05]]
# M_liq: [44.0095, 43.209695]
# M_vap: [34.41336134, 43.209695]
# rho_liq: [1074.620135, -9999990.0]
# rho_vap: [92.243987, -9999990.0]
# --- End ---
#
# T=247.00 K | evaluating at P_bubble=46.249472 bar, P_dew=17.279401 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 247.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [46.249472, 17.279401]
# gamma_Parachor_mN_m: [7.92187035, 9.54914159]
# gamma_WSD_mN_m: [9.76740857, 9.60159139]
# x: [[1.0, 0.0], [0.998391, 0.001609]]
# y: [[0.408547, 0.591453], [0.949996, 0.050004]]
# M_liq: [44.0095, 43.98376216]
# M_vap: [34.54855381, 43.20963498]
# rho_liq: [1070.492101, 1057.937304]
# rho_vap: [93.221086, 44.204484]
# --- End ---
#
# T=248.00 K | evaluating at P_bubble=46.616551 bar, P_dew=17.853402 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 248.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [46.616551, 17.853402]
# gamma_Parachor_mN_m: [7.7614745, 9.33423988]
# gamma_WSD_mN_m: [9.55977223, 9.38796119]
# x: [[1.0, 0.0], [0.99832, 0.00168]]
# y: [[0.416973, 0.583027], [0.949996, 0.050004]]
# M_liq: [44.0095, 43.98262124]
# M_vap: [34.68333815, 43.20963531]
# rho_liq: [1066.334899, 1053.506809]
# rho_vap: [94.238059, 45.715488]
# --- End ---
#
# T=249.00 K | evaluating at P_bubble=46.997895 bar, P_dew=18.441540 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 249.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [46.997895, 18.44154]
# gamma_Parachor_mN_m: [7.60155606, 9.12023634]
# gamma_WSD_mN_m: [9.35327811, 9.17525215]
# x: [[1.0, 0.0], [0.998245, 0.001755]]
# y: [[0.425368, 0.574632], [0.949996, 0.050004]]
# M_liq: [44.0095, 43.98143441]
# M_vap: [34.81762137, 43.20963565]
# rho_liq: [1062.147683, 1049.034595]
# rho_vap: [95.295111, 47.271178]
# --- End ---
#
# T=250.00 K | evaluating at P_bubble=47.393544 bar, P_dew=19.044049 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 250.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [47.393544, 19.044049]
# gamma_Parachor_mN_m: [7.44216001, 8.90714357]
# gamma_WSD_mN_m: [9.14794274, 8.96347732]
# x: [[1.0, 0.0], [0.998168, 0.001832]]
# y: [[0.433725, 0.566275], [0.949996, 0.050004]]
# M_liq: [44.0095, 43.98019972]
# M_vap: [34.95131017, 43.20963601]
# rho_liq: [1057.929573, 1044.519175]
# rho_vap: [96.392504, 48.87297]
# --- End ---
#
# T=251.00 K | evaluating at P_bubble=47.803534 bar, P_dew=19.661168 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 251.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [47.803534, 19.661168]
# gamma_Parachor_mN_m: [5.80081058, 8.69497459]
# gamma_WSD_mN_m: [6.89841659, 8.75265021]
# x: [[0.950001, 0.049999], [0.998088, 0.001912]]
# y: [[0.508645, 0.491355], [0.949996, 0.050004]]
# M_liq: [43.20970318, 43.97891509]
# M_vap: [36.14974222, 43.20963637]
# rho_liq: [998.10658, 1039.958986]
# rho_vap: [105.059184, 50.522346]
# --- End ---
#
# T=252.00 K | evaluating at P_bubble=48.227903 bar, P_dew=20.293139 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 252.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [48.227903, 20.293139]
# gamma_Parachor_mN_m: [5.64416137, 8.48374297]
# gamma_WSD_mN_m: [6.71975426, 8.54278478]
# x: [[0.950001, 0.049999], [0.998004, 0.001996]]
# y: [[0.518879, 0.481121], [0.949996, 0.050004]]
# M_liq: [43.20970317, 43.97757833]
# M_vap: [36.31343673, 43.20963673]
# rho_liq: [993.304902, 1035.352386]
# rho_vap: [106.642432, 52.220863]
# --- End ---
#
# T=253.00 K | evaluating at P_bubble=48.666690 bar, P_dew=20.940208 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 253.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [48.66669, 20.940208]
# gamma_Parachor_mN_m: [5.48799914, 8.27346261]
# gamma_WSD_mN_m: [6.54205397, 8.33389545]
# x: [[0.950001, 0.049999], [0.997917, 0.002083]]
# y: [[0.529078, 0.470922], [0.949996, 0.050004]]
# M_liq: [43.20970317, 43.97618711]
# M_vap: [36.47658076, 43.20963709]
# rho_liq: [988.448826, 1030.697644]
# rho_vap: [108.289931, 53.97016]
# --- End ---
#
# T=254.00 K | evaluating at P_bubble=49.119928 bar, P_dew=21.602625 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 254.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [49.119928, 21.602625]
# gamma_Parachor_mN_m: [5.33236812, 8.06414793]
# gamma_WSD_mN_m: [6.36533478, 8.12599713]
# x: [[0.950001, 0.049999], [0.997827, 0.002173]]
# y: [[0.539236, 0.460764], [0.949996, 0.050004]]
# M_liq: [43.20970318, 43.97473896]
# M_vap: [36.63907502, 43.20963746]
# rho_liq: [983.536227, 1025.992937]
# rho_vap: [110.003344, 55.77196]
# --- End ---
#
# T=255.00 K | evaluating at P_bubble=49.587654 bar, P_dew=22.280645 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 255.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [49.587654, 22.280645]
# gamma_Parachor_mN_m: [5.17731279, 7.85581386]
# gamma_WSD_mN_m: [6.18961634, 7.91910525]
# x: [[0.950001, 0.049999], [0.997733, 0.002267]]
# y: [[0.549348, 0.450652], [0.949996, 0.050004]]
# M_liq: [43.2097032, 43.97323126]
# M_vap: [36.8008248, 43.20963784]
# rho_liq: [978.564864, 1021.236344]
# rho_vap: [111.784445, 57.628081]
# --- End ---
#
# T=256.00 K | evaluating at P_bubble=50.069899 bar, P_dew=22.974528 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 256.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [50.069899, 22.974528]
# gamma_Parachor_mN_m: [5.02287793, 7.64847589]
# gamma_WSD_mN_m: [6.01491893, 7.71323582]
# x: [[0.950001, 0.049999], [0.997634, 0.002366]]
# y: [[0.559408, 0.440592], [0.949996, 0.050004]]
# M_liq: [43.20970322, 43.97166121]
# M_vap: [36.9617403, 43.20963822]
# rho_liq: [973.532365, 1016.425835]
# rho_vap: [113.635129, 59.54044]
# --- End ---
#
# T=257.00 K | evaluating at P_bubble=50.566690 bar, P_dew=23.684540 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 257.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [50.56669, 23.68454]
# gamma_Parachor_mN_m: [4.86910922, 7.44215005]
# gamma_WSD_mN_m: [5.84126374, 7.5084054]
# x: [[0.950001, 0.049999], [0.997532, 0.002468]]
# y: [[0.56941, 0.43059], [0.949996, 0.050004]]
# M_liq: [43.20970338, 43.97002585]
# M_vap: [37.12173716, 43.20963861]
# rho_liq: [968.436225, 1011.559263]
# rho_vap: [115.557406, 61.511064]
# --- End ---
#
# T=258.00 K | evaluating at P_bubble=51.078071 bar, P_dew=24.410950 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 258.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [51.078071, 24.41095]
# gamma_Parachor_mN_m: [4.71605105, 7.23685299]
# gamma_WSD_mN_m: [5.66867157, 7.30463119]
# x: [[0.950001, 0.049999], [0.997426, 0.002574]]
# y: [[0.57935, 0.42065], [0.949996, 0.050004]]
# M_liq: [43.20970334, 43.968322]
# M_vap: [37.28073515, 43.209639]
# rho_liq: [963.27377, 1006.634358]
# rho_vap: [117.553481, 63.542097]
# --- End ---
#
# T=259.00 K | evaluating at P_bubble=51.604057 bar, P_dew=25.154036 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 259.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [51.604057, 25.154036]
# gamma_Parachor_mN_m: [0.0, 7.03260202]
# gamma_WSD_mN_m: [0.0, 7.10193102]
# x: [[0.95, 0.05], [0.997315, 0.002685]]
# y: [[0.95, 0.05], [0.949997, 0.050003]]
# M_liq: [43.209695, 43.96654628]
# M_vap: [43.209695, 43.20963941]
# rho_liq: [-9999990.0, 1001.648713]
# rho_vap: [-9999990.0, 65.635811]
# --- End ---
#
# T=260.00 K | evaluating at P_bubble=52.144672 bar, P_dew=25.914080 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 260.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [52.144672, 25.91408]
# gamma_Parachor_mN_m: [0.0, 6.82941512]
# gamma_WSD_mN_m: [0.0, 6.90032344]
# x: [[0.95, 0.05], [0.997199, 0.002801]]
# y: [[0.95, 0.05], [0.949997, 0.050003]]
# M_liq: [43.209695, 43.96469506]
# M_vap: [43.209695, 43.20963982]
# rho_liq: [-9999990.0, 996.599776]
# rho_vap: [-9999990.0, 67.794617]
# --- End ---
#
# T=261.00 K | evaluating at P_bubble=52.699928 bar, P_dew=26.691374 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 261.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [52.699928, 26.691374]
# gamma_Parachor_mN_m: [0.0, 6.627311]
# gamma_WSD_mN_m: [0.0, 6.6998277]
# x: [[0.95, 0.05], [0.997078, 0.002922]]
# y: [[0.95, 0.05], [0.949997, 0.050003]]
# M_liq: [43.209695, 43.96276446]
# M_vap: [43.209695, 43.20964023]
# rho_liq: [-9999990.0, 991.484835]
# rho_vap: [-9999990.0, 70.021081]
# --- End ---
#
# T=262.00 K | evaluating at P_bubble=53.269856 bar, P_dew=27.486214 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 262.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [53.269856, 27.486214]
# gamma_Parachor_mN_m: [0.0, 6.42630915]
# gamma_WSD_mN_m: [0.0, 6.50046387]
# x: [[0.95, 0.05], [0.996952, 0.003048]]
# y: [[0.95, 0.05], [0.949997, 0.050003]]
# M_liq: [43.209695, 43.96075031]
# M_vap: [43.209695, 43.20964066]
# rho_liq: [-9999990.0, 986.301003]
# rho_vap: [-9999990.0, 72.317931]
# --- End ---
#
# T=263.00 K | evaluating at P_bubble=53.854461 bar, P_dew=28.298907 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 263.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [53.854461, 28.298907]
# gamma_Parachor_mN_m: [0.0, 6.22642991]
# gamma_WSD_mN_m: [0.0, 6.30225281]
# x: [[0.95, 0.05], [0.996821, 0.003179]]
# y: [[0.95, 0.05], [0.949997, 0.050003]]
# M_liq: [43.209695, 43.95864813]
# M_vap: [43.209695, 43.20964109]
# rho_liq: [-9999990.0, 981.045206]
# rho_vap: [-9999990.0, 74.68808]
# --- End ---
#
# T=264.00 K | evaluating at P_bubble=54.453752 bar, P_dew=29.129767 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 264.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [54.453752, 29.129767]
# gamma_Parachor_mN_m: [0.0, 6.02769451]
# gamma_WSD_mN_m: [0.0, 6.1052163]
# x: [[0.95, 0.05], [0.996684, 0.003316]]
# y: [[0.95, 0.05], [0.949997, 0.050003]]
# M_liq: [43.209695, 43.95645308]
# M_vap: [43.209695, 43.20964153]
# rho_liq: [-9999990.0, 975.714162]
# rho_vap: [-9999990.0, 77.134638]
# --- End ---
#
# T=265.00 K | evaluating at P_bubble=55.067730 bar, P_dew=29.979118 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 265.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [55.06773, 29.979118]
# gamma_Parachor_mN_m: [0.0, 5.83012515]
# gamma_WSD_mN_m: [0.0, 5.90937704]
# x: [[0.95, 0.05], [0.99654, 0.00346]]
# y: [[0.95, 0.05], [0.949997, 0.050003]]
# M_liq: [43.209695, 43.95415997]
# M_vap: [43.209695, 43.20964198]
# rho_liq: [-9999990.0, 970.304365]
# rho_vap: [-9999990.0, 79.660935]
# --- End ---
#
# T=266.00 K | evaluating at P_bubble=55.696392 bar, P_dew=30.847296 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 266.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [55.696392, 30.847296]
# gamma_Parachor_mN_m: [0.0, 5.63374506]
# gamma_WSD_mN_m: [0.0, 5.71475876]
# x: [[0.95, 0.05], [0.996391, 0.003609]]
# y: [[0.95, 0.05], [0.949997, 0.050003]]
# M_liq: [43.209695, 43.95176315]
# M_vap: [43.209695, 43.20964243]
# rho_liq: [-9999990.0, 964.812058]
# rho_vap: [-9999990.0, 82.270546]
# --- End ---
#
# T=267.00 K | evaluating at P_bubble=56.339727 bar, P_dew=31.734647 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 267.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [56.339727, 31.734647]
# gamma_Parachor_mN_m: [3.37842287, 5.43857862]
# gamma_WSD_mN_m: [4.16716006, 5.52138629]
# x: [[0.950001, 0.049999], [0.996234, 0.003766]]
# y: [[0.665356, 0.334644], [0.949997, 0.050003]]
# M_liq: [43.20970521, 43.94925652]
# M_vap: [38.6565065, 43.2096429]
# rho_liq: [913.296331, 959.23321]
# rho_vap: [139.284666, 84.967308]
# --- End ---
#
# T=268.00 K | evaluating at P_bubble=56.997716 bar, P_dew=32.641528 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 268.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [56.997716, 32.641528]
# gamma_Parachor_mN_m: [3.23516077, 5.2446514]
# gamma_WSD_mN_m: [4.00657548, 5.3292856]
# x: [[0.950001, 0.049999], [0.99607, 0.00393]]
# y: [[0.674477, 0.325523], [0.949997, 0.050003]]
# M_liq: [43.20970512, 43.94663344]
# M_vap: [38.80240738, 43.20964337]
# rho_liq: [907.280509, 953.563489]
# rho_vap: [142.180062, 87.75536]
# --- End ---
#
# T=269.00 K | evaluating at P_bubble=57.670334 bar, P_dew=33.568314 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 269.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [57.670334, 33.568314]
# gamma_Parachor_mN_m: [3.09317292, 5.0519903]
# gamma_WSD_mN_m: [3.84735298, 5.13848392]
# x: [[0.950001, 0.049999], [0.995898, 0.004102]]
# y: [[0.683505, 0.316495], [0.949997, 0.050003]]
# M_liq: [43.2097054, 43.9438867]
# M_vap: [38.94681625, 43.20964385]
# rho_liq: [901.154409, 947.798228]
# rho_vap: [145.1874, 90.639167]
# --- End ---
#
# T=270.00 K | evaluating at P_bubble=58.357551 bar, P_dew=34.515391 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 270.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [58.357551, 34.515391]
# gamma_Parachor_mN_m: [2.95251921, 4.86062367]
# gamma_WSD_mN_m: [3.68952684, 4.94900986]
# x: [[0.950001, 0.049999], [0.995718, 0.004282]]
# y: [[0.692439, 0.307561], [0.949997, 0.050003]]
# M_liq: [43.20970547, 43.9410084]
# M_vap: [39.08972032, 43.20964434]
# rho_liq: [894.911966, 941.932384]
# rho_vap: [148.312138, 93.623565]
# --- End ---
#
# T=271.00 K | evaluating at P_bubble=59.059299 bar, P_dew=35.483164 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 271.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [59.059299, 35.483164]
# gamma_Parachor_mN_m: [2.81326415, 4.67058145]
# gamma_WSD_mN_m: [3.53313487, 4.76089347]
# x: [[0.950001, 0.049999], [0.99553, 0.00447]]
# y: [[0.701278, 0.298722], [0.949997, 0.050003]]
# M_liq: [43.20970592, 43.93798992]
# M_vap: [39.23111623, 43.20964485]
# rho_liq: [888.546684, 935.960503]
# rho_vap: [151.560194, 96.7138]
# --- End ---
#
# T=272.00 K | evaluating at P_bubble=59.775517 bar, P_dew=36.472057 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 272.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [59.775517, 36.472057]
# gamma_Parachor_mN_m: [2.67547346, 4.48189527]
# gamma_WSD_mN_m: [3.37821552, 4.57416641]
# x: [[0.950001, 0.049999], [0.995331, 0.004669]]
# y: [[0.710023, 0.289977], [0.949997, 0.050003]]
# M_liq: [43.20970605, 43.9348218]
# M_vap: [39.37100148, 43.20964536]
# rho_liq: [882.051381, 929.876662]
# rho_vap: [154.938052, 99.91558]
# --- End ---
#
# T=273.00 K | evaluating at P_bubble=60.506137 bar, P_dew=37.482513 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 273.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [60.506137, 37.482513]
# gamma_Parachor_mN_m: [2.53921598, 4.2945987]
# gamma_WSD_mN_m: [3.22481021, 4.38886206]
# x: [[0.950001, 0.049999], [0.995123, 0.004877]]
# y: [[0.718674, 0.281326], [0.949997, 0.050003]]
# M_liq: [43.20970692, 43.93149361]
# M_vap: [39.50938765, 43.20964588]
# rho_liq: [875.418411, 923.674413]
# rho_vap: [158.453031, 103.235136]
# --- End ---
#
# T=274.00 K | evaluating at P_bubble=61.251109 bar, P_dew=38.515000 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 274.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [61.251109, 38.515]
# gamma_Parachor_mN_m: [2.40456128, 4.10872732]
# gamma_WSD_mN_m: [3.07296, 4.20501563]
# x: [[0.950001, 0.049999], [0.994905, 0.005095]]
# y: [[0.727232, 0.272768], [0.949997, 0.050003]]
# M_liq: [43.20970656, 43.92799384]
# M_vap: [39.64628061, 43.20964643]
# rho_liq: [868.639121, 917.346718]
# rho_vap: [162.113144, 106.679294]
# --- End ---
#
# T=275.00 K | evaluating at P_bubble=62.010295 bar, P_dew=39.570011 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 275.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [62.010295, 39.570011]
# gamma_Parachor_mN_m: [2.2715878, 3.9243193]
# gamma_WSD_mN_m: [2.92271251, 4.02266454]
# x: [[0.950001, 0.049999], [0.994674, 0.005326]]
# y: [[0.735698, 0.264302], [0.949997, 0.050003]]
# M_liq: [43.20970598, 43.92430974]
# M_vap: [39.78170156, 43.20964696]
# rho_liq: [861.704233, 910.885867]
# rho_vap: [165.92713, 110.255535]
# --- End ---
#
# T=276.00 K | evaluating at P_bubble=62.783431 bar, P_dew=40.648070 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 276.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [62.783431, 40.64807]
# gamma_Parachor_mN_m: [2.1403848, 3.74141496]
# gamma_WSD_mN_m: [2.77412268, 3.84184821]
# x: [[0.950001, 0.049999], [0.994432, 0.005568]]
# y: [[0.744074, 0.255926], [0.949997, 0.050003]]
# M_liq: [43.20970842, 43.92042712]
# M_vap: [39.91568115, 43.20964751]
# rho_liq: [854.603613, 904.283381]
# rho_vap: [169.904276, 113.972134]
# --- End ---
#
# T=277.00 K | evaluating at P_bubble=63.570541 bar, P_dew=41.749732 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 277.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [63.570541, 41.749732]
# gamma_Parachor_mN_m: [2.0110263, 3.56005741]
# gamma_WSD_mN_m: [2.62723421, 3.66260851]
# x: [[0.950001, 0.049999], [0.994175, 0.005825]]
# y: [[0.752361, 0.247639], [0.949997, 0.050003]]
# M_liq: [43.20970826, 43.91633013]
# M_vap: [40.04823679, 43.20964816]
# rho_liq: [847.325439, 897.529903]
# rho_vap: [174.056044, 117.838248]
# --- End ---
#
# T=278.00 K | evaluating at P_bubble=64.371286 bar, P_dew=42.875592 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 278.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [64.371286, 42.875592]
# gamma_Parachor_mN_m: [1.88361325, 3.38029389]
# gamma_WSD_mN_m: [2.48210987, 3.48499043]
# x: [[0.950001, 0.049999], [0.993905, 0.006095]]
# y: [[0.760561, 0.239439], [0.949997, 0.050003]]
# M_liq: [43.20970991, 43.91200099]
# M_vap: [40.17941637, 43.20964876]
# rho_liq: [839.857249, 890.615058]
# rho_vap: [178.394154, 121.864007]
# --- End ---
#
# T=279.00 K | evaluating at P_bubble=65.185543 bar, P_dew=44.026290 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 279.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [65.185543, 44.02629]
# gamma_Parachor_mN_m: [1.758237, 3.20217435]
# gamma_WSD_mN_m: [2.33880448, 3.30904152]
# x: [[0.950001, 0.049999], [0.993618, 0.006382]]
# y: [[0.768678, 0.231322], [0.949997, 0.050003]]
# M_liq: [43.20970934, 43.90741968]
# M_vap: [40.30925486, 43.20964938]
# rho_liq: [832.184429, 883.52729]
# rho_vap: [182.93261, 126.060772]
# --- End ---
#
# T=280.00 K | evaluating at P_bubble=66.012932 bar, P_dew=45.202515 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 280.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [66.012932, 45.202515]
# gamma_Parachor_mN_m: [1.63500913, 3.02575306]
# gamma_WSD_mN_m: [2.19738678, 3.13481272]
# x: [[0.950001, 0.049999], [0.993315, 0.006685]]
# y: [[0.776715, 0.223285], [0.949997, 0.050003]]
# M_liq: [43.20970875, 43.90256349]
# M_vap: [40.43780909, 43.20965002]
# rho_liq: [824.290955, 876.253661]
# rho_vap: [187.68647, 130.441275]
# --- End ---
#
# T=281.00 K | evaluating at P_bubble=66.853152 bar, P_dew=46.405015 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 281.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [66.853152, 46.405015]
# gamma_Parachor_mN_m: [1.51404163, 2.85108894]
# gamma_WSD_mN_m: [2.05792493, 2.96235861]
# x: [[0.950001, 0.049999], [0.992992, 0.007008]]
# y: [[0.784675, 0.215325], [0.949997, 0.050003]]
# M_liq: [43.20970754, 43.89740655]
# M_vap: [40.5651415, 43.20965068]
# rho_liq: [816.158505, 868.779599]
# rho_vap: [192.673526, 135.019879]
# --- End ---
#
# T=282.00 K | evaluating at P_bubble=67.705666 bar, P_dew=47.634609 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 282.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [67.705666, 47.634609]
# gamma_Parachor_mN_m: [1.3954656, 2.67824615]
# gamma_WSD_mN_m: [1.92049941, 2.79173781]
# x: [[0.950001, 0.049999], [0.992649, 0.007351]]
# y: [[0.792564, 0.207436], [0.949997, 0.050003]]
# M_liq: [43.20970907, 43.89191922]
# M_vap: [40.69133039, 43.20965136]
# rho_liq: [807.766339, 861.088591]
# rho_vap: [197.913329, 139.812886]
# --- End ---
#
# T=283.00 K | evaluating at P_bubble=68.569909 bar, P_dew=48.892197 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 283.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [68.569909, 48.892197]
# gamma_Parachor_mN_m: [1.27941919, 2.50729488]
# gamma_WSD_mN_m: [1.78519406, 2.62301341]
# x: [[0.950001, 0.049999], [0.992284, 0.007716]]
# y: [[0.800386, 0.199614], [0.949997, 0.050003]]
# M_liq: [43.2097149, 43.88606725]
# M_vap: [40.81646239, 43.20965206]
# rho_liq: [799.090398, 853.161786]
# rho_vap: [203.428681, 144.838917]
# --- End ---
#
# T=284.00 K | evaluating at P_bubble=69.445567 bar, P_dew=50.178776 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 284.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [69.445567, 50.178776]
# gamma_Parachor_mN_m: [1.16603432, 2.33831488]
# gamma_WSD_mN_m: [1.65208439, 2.45625491]
# x: [[0.950001, 0.049999], [0.991892, 0.008108]]
# y: [[0.808148, 0.191852], [0.949997, 0.050003]]
# M_liq: [43.20971278, 43.8798108]
# M_vap: [40.94061049, 43.20965207]
# rho_liq: [790.101459, 844.977497]
# rho_vap: [209.247277, 150.119202]
# --- End ---
#
# T=285.00 K | evaluating at P_bubble=70.331627 bar, P_dew=51.495464 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 285.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [70.331627, 51.495464]
# gamma_Parachor_mN_m: [1.05548925, 0.0]
# gamma_WSD_mN_m: [1.52127843, 0.0]
# x: [[0.950001, 0.049999], [0.95, 0.05]]
# y: [[0.815856, 0.184144], [0.95, 0.05]]
# M_liq: [43.20971091, 43.209695]
# M_vap: [41.06390734, 43.209695]
# rho_liq: [780.767035, -9999990.0]
# rho_vap: [215.399416, -9999990.0]
# --- End ---
#
# T=286.00 K | evaluating at P_bubble=71.227052 bar, P_dew=52.843521 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 286.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [71.227052, 52.843521]
# gamma_Parachor_mN_m: [0.94797184, 2.00660334]
# gamma_WSD_mN_m: [1.39288673, 2.12892794]
# x: [[0.950001, 0.049999], [0.991022, 0.008978]]
# y: [[0.823519, 0.176481], [0.949997, 0.050003]]
# M_liq: [43.20971145, 43.86588884]
# M_vap: [41.18649263, 43.20965423]
# rho_liq: [771.047879, 827.731423]
# rho_vap: [221.921421, 161.547433]
# --- End ---
#
# T=287.00 K | evaluating at P_bubble=72.130648 bar, P_dew=54.224389 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 287.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [72.130648, 54.224389]
# gamma_Parachor_mN_m: [0.84368873, 1.84407698]
# gamma_WSD_mN_m: [1.26702816, 1.9685286]
# x: [[0.950001, 0.049999], [0.990535, 0.009465]]
# y: [[0.831148, 0.168852], [0.949997, 0.050003]]
# M_liq: [43.20971327, 43.85810153]
# M_vap: [41.30852545, 43.20965499]
# rho_liq: [760.896446, 818.605082]
# rho_vap: [228.856899, 167.758542]
# --- End ---
#
# T=288.00 K | evaluating at P_bubble=73.040909 bar, P_dew=55.639734 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 288.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [73.040909, 55.639734]
# gamma_Parachor_mN_m: [0.74287588, 1.68392331]
# gamma_WSD_mN_m: [1.14383622, 1.81042797]
# x: [[0.950001, 0.049999], [0.990008, 0.009992]]
# y: [[0.838754, 0.161246], [0.949998, 0.050002]]
# M_liq: [43.20971467, 43.84966064]
# M_vap: [41.43019583, 43.20965575]
# rho_liq: [750.254745, 809.089426]
# rho_vap: [236.258323, 174.353755]
# --- End ---
#
# T=289.00 K | evaluating at P_bubble=73.955986 bar, P_dew=57.091512 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 289.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [73.955986, 57.091512]
# gamma_Parachor_mN_m: [0.64580388, 1.52627678]
# gamma_WSD_mN_m: [1.02346081, 1.65472847]
# x: [[0.950001, 0.049999], [0.989433, 0.010567]]
# y: [[0.846352, 0.153648], [0.949998, 0.050002]]
# M_liq: [43.20971175, 43.84046699]
# M_vap: [41.55173268, 43.20965647]
# rho_liq: [739.051079, 799.133069]
# rho_vap: [244.190209, 181.383102]
# --- End ---
#
# T=290.00 K | evaluating at P_bubble=74.873160 bar, P_dew=58.582056 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 290.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [74.87316, 58.582056]
# gamma_Parachor_mN_m: [0.55280649, 1.37129117]
# gamma_WSD_mN_m: [0.90608904, 1.50154145]
# x: [[0.950001, 0.049999], [0.988803, 0.011197]]
# y: [[0.85396, 0.14604], [0.949998, 0.050002]]
# M_liq: [43.20971184, 43.83039639]
# M_vap: [41.67343111, 43.2096571]
# rho_liq: [727.196778, 788.672194]
# rho_vap: [252.730516, 188.908257]
# --- End ---
#
# T=291.00 K | evaluating at P_bubble=75.789040 bar, P_dew=60.114206 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 291.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [75.78904, 60.114206]
# gamma_Parachor_mN_m: [0.46427719, 1.21914469]
# gamma_WSD_mN_m: [0.79193936, 1.35098773]
# x: [[0.950002, 0.049998], [0.988109, 0.011891]]
# y: [[0.861602, 0.138398], [0.949998, 0.050002]]
# M_liq: [43.20972644, 43.81929016]
# M_vap: [41.79566483, 43.20965745]
# rho_liq: [714.580306, 777.625932]
# rho_vap: [261.979141, 197.00664]
# --- End ---
#
# T=292.00 K | evaluating at P_bubble=76.700249 bar, P_dew=61.691498 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 292.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [76.700249, 61.691498]
# gamma_Parachor_mN_m: [0.0, 1.07003894]
# gamma_WSD_mN_m: [0.0, 1.20319305]
# x: [[0.95, 0.05], [0.987337, 0.012663]]
# y: [[0.95, 0.05], [0.949998, 0.050002]]
# M_liq: [43.209695, 43.80694082]
# M_vap: [43.209695, 43.2096604]
# rho_liq: [-9999990.0, 765.88941]
# rho_vap: [-9999990.0, 205.778749]
# --- End ---
#
# T=293.00 K | evaluating at P_bubble=77.600292 bar, P_dew=63.318464 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 293.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [77.600292, 63.318464]
# gamma_Parachor_mN_m: [0.0, 0.92423607]
# gamma_WSD_mN_m: [2e-08, 1.05830209]
# x: [[0.95, 0.05], [0.98647, 0.01353]]
# y: [[0.949992, 0.050008], [0.949998, 0.050002]]
# M_liq: [43.209695, 43.79306916]
# M_vap: [43.20955928, 43.20966198]
# rho_liq: [686.411851, 753.322811]
# rho_vap: [686.33722, 215.354522]
# --- End ---
#
# T=294.00 K | evaluating at P_bubble=78.481461 bar, P_dew=65.001117 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 294.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [78.481461, 65.001117]
# gamma_Parachor_mN_m: [0.2306766, 0.78204405]
# gamma_WSD_mN_m: [0.47161728, 0.91645739]
# x: [[0.95, 0.05], [0.985483, 0.014517]]
# y: [[0.885033, 0.114967], [0.949998, 0.050002]]
# M_liq: [43.209695, 43.77728623]
# M_vap: [42.17047183, 43.20966366]
# rho_liq: [670.406661, 739.733722]
# rho_vap: [295.496615, 225.913542]
# --- End ---
#
# T=295.00 K | evaluating at P_bubble=79.332219 bar, P_dew=66.747798 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 295.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [79.332219, 66.747798]
# gamma_Parachor_mN_m: [0.16595869, 0.64386605]
# gamma_WSD_mN_m: [0.3736344, 0.77780307]
# x: [[0.95, 0.05], [0.984342, 0.015658]]
# y: [[0.89318, 0.10682], [0.949998, 0.050002]]
# M_liq: [43.209695, 43.75902588]
# M_vap: [42.30080224, 43.20966546]
# rho_liq: [652.646726, 724.846547]
# rho_vap: [309.390428, 237.710726]
# --- End ---
#
# T=296.00 K | evaluating at P_bubble=80.135340 bar, P_dew=68.570776 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 296.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [80.13534, 68.570776]
# gamma_Parachor_mN_m: [0.10958061, 0.51025043]
# gamma_WSD_mN_m: [0.2811364, 0.64246392]
# x: [[0.95, 0.05], [0.982991, 0.017009]]
# y: [[0.901627, 0.098373], [0.949998, 0.050002]]
# M_liq: [43.209695, 43.73741517]
# M_vap: [42.43591683, 43.20966695]
# rho_liq: [632.559825, 708.24539]
# rho_vap: [325.303409, 251.12975]
# --- End ---
#
# T=297.00 K | evaluating at P_bubble=80.865577 bar, P_dew=70.489659 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 297.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [80.865577, 70.489659]
# gamma_Parachor_mN_m: [0.06112089, 0.38197861]
# gamma_WSD_mN_m: [0.19215552, 0.51048417]
# x: [[0.95, 0.05], [0.981339, 0.018661]]
# y: [[0.910973, 0.089027], [0.949998, 0.050002]]
# M_liq: [43.209695, 43.71099341]
# M_vap: [42.58542241, 43.20966563]
# rho_liq: [609.286827, 689.253109]
# rho_vap: [346.123536, 266.796234]
# --- End ---
#
# T=298.00 K | evaluating at P_bubble=81.490855 bar, P_dew=72.539460 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 298.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [81.490855, 72.53946]
# gamma_Parachor_mN_m: [0.02732065, 0.2602636]
# gamma_WSD_mN_m: [0.11574107, 0.38165512]
# x: [[0.95, 0.05], [0.979214, 0.020786]]
# y: [[0.920417, 0.079583], [0.949998, 0.050002]]
# M_liq: [43.209695, 43.67701139]
# M_vap: [42.73648213, 43.20966416]
# rho_liq: [581.628317, 666.627648]
# rho_vap: [368.915591, 285.848288]
# --- End ---
#
# T=299.00 K | evaluating at P_bubble=81.966461 bar, P_dew=74.796544 bar
# Given temperature is greater than Tc (126.192) for Nitrogen
# Computing interfacial tension at T = 0.9*126.192 for Parachor method
#
# --- Results ---
# Temperature           : 299.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [81.966461, 74.796544]
# gamma_Parachor_mN_m: [0.0, 0.14718452]
# gamma_WSD_mN_m: [1.4e-05, 0.25482543]
# x: [[0.95, 0.05], [0.976219, 0.023781]]
# y: [[0.949743, 0.050257], [0.949998, 0.050002]]
# M_liq: [43.209695, 43.62910362]
# M_vap: [43.20558514, 43.20966529]
# rho_liq: [547.802144, 637.570386]
# rho_vap: [545.357633, 310.803027]
# --- End ---

# %%
# --- choose which surface tension to use for SHL ---
GAMMA_KEY = "gamma_Parachor_mN_m"  # or "gamma_WSD_mN_m"

# --- choose which side to compute ---
SIDE = "dew"      # "bubble", "dew", or "both"
# -----------------------------------

def collect_shl_points(results_all, side):
    points = []
    for rec in results_all:
        T_K = rec["T_K"]
        keyed = {s["point_type"]: s for s in rec["samples"]}

        s = keyed.get(side)
        if s is None:
            print(f"[skip] T={T_K:.2f} K | missing {side} sample")
            continue

        Psat_Pa   = s["P_bar"] * 1e5
        gamma_N_m = s[GAMMA_KEY] * 1e-3
        rho_L     = s["rho_liq_kg_per_m3"]
        x_list    = s["x"]

        # Basic sanity checks
        if gamma_N_m <= 0.0:
            print(f"[skip] T={T_K:.2f} K, {side:5s} | gamma<=0 from {GAMMA_KEY} (γ={gamma_N_m:.3e} N/m) — near Tc?")
            continue
        if rho_L <= 0.0:
            print(f"[skip] T={T_K:.2f} K, {side:5s} | rho_L invalid ({rho_L:g})")
            continue
        if abs(sum(x_list) - 1.0) > 1e-8:
            print(f"[skip] T={T_K:.2f} K, {side:5s} | x does not sum to 1 (sum={sum(x_list):.6f})")
            continue

        points.append({
            "T_K": T_K,
            "Psat_Pa": Psat_Pa,
            "gamma_N_m": gamma_N_m,
            "rho_L": rho_L,
            "x_list": x_list,
            "meta": {"point_type": side, "P_bar": s["P_bar"], "y_list": s["y"]},
        })
    return points

# --- run SHL only on valid points; skip those failing CNT conditions ---
M_CO2, M_N2 = 44.00985e-3, 28.0134e-3
M_list = [M_CO2, M_N2]
Jcrit = 1e12

def run_shl(points, label):
    results = []
    for row in points:
        try:
            shl = SHLMixture(
                Jcrit=Jcrit,
                Psat=row["Psat_Pa"],
                T=row["T_K"],
                gamma=row["gamma_N_m"],
                rho_L=row["rho_L"],
                M_list=M_list,
                x_list=row["x_list"],
            )
            DeltaP, Pc, rc = shl.compute()
            results.append({"T_K": row["T_K"], "Pc_bar": Pc/1e5, "DeltaP_Pa": DeltaP, "rc_m": rc})
        except ValueError as e:
            print(f"[skip] T={row['T_K']:.2f} K, {label:5s} | {e}")
            continue
    return results

if SIDE in ("bubble", "dew"):
    shl_points   = collect_shl_points(results_all, SIDE)
    shl_results  = run_shl(shl_points, SIDE)
    csv_filename = f"SHL_CO2_N2_{SIDE}.csv"

    with open(csv_filename, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["T_K", "Pc_bar"])
        for r in shl_results:
            print(f"T={r['T_K']:.2f} K | SHL {SIDE} Pc = {r['Pc_bar']:.3f} bar")
            writer.writerow([r["T_K"], r["Pc_bar"]])

elif SIDE == "both":
    for side in ("bubble", "dew"):
        shl_points  = collect_shl_points(results_all, side)
        shl_results = run_shl(shl_points, side)
        csv_filename = f"SHL_CO2_N2_{side}.csv"

        with open(csv_filename, "w", newline="") as f:
            writer = csv.writer(f)
            writer.writerow(["T_K", "Pc_bar"])
            for r in shl_results:
                print(f"T={r['T_K']:.2f} K | SHL {side} Pc = {r['Pc_bar']:.3f} bar")
                writer.writerow([r["T_K"], r["Pc_bar"]])
else:
    raise ValueError("SIDE must be 'bubble', 'dew', or 'both'.")
# Out:
# [skip] T=220.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=221.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=222.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=223.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=224.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=225.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=226.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=227.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=228.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=229.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=230.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=231.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=232.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=233.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=234.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=235.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=237.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=238.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=239.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=240.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=241.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=242.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=243.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=244.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=245.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=246.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=285.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# T=236.00 K | SHL dew Pc = -105.766 bar
# T=247.00 K | SHL dew Pc = -64.737 bar
# T=248.00 K | SHL dew Pc = -61.260 bar
# T=249.00 K | SHL dew Pc = -57.823 bar
# T=250.00 K | SHL dew Pc = -54.425 bar
# T=251.00 K | SHL dew Pc = -51.066 bar
# T=252.00 K | SHL dew Pc = -47.746 bar
# T=253.00 K | SHL dew Pc = -44.464 bar
# T=254.00 K | SHL dew Pc = -41.220 bar
# T=255.00 K | SHL dew Pc = -38.013 bar
# T=256.00 K | SHL dew Pc = -34.843 bar
# T=257.00 K | SHL dew Pc = -31.709 bar
# T=258.00 K | SHL dew Pc = -28.612 bar
# T=259.00 K | SHL dew Pc = -25.549 bar
# T=260.00 K | SHL dew Pc = -22.522 bar
# T=261.00 K | SHL dew Pc = -19.529 bar
# T=262.00 K | SHL dew Pc = -16.570 bar
# T=263.00 K | SHL dew Pc = -13.645 bar
# T=264.00 K | SHL dew Pc = -10.753 bar
# T=265.00 K | SHL dew Pc = -7.894 bar
# T=266.00 K | SHL dew Pc = -5.068 bar
# T=267.00 K | SHL dew Pc = -2.273 bar
# T=268.00 K | SHL dew Pc = 0.491 bar
# T=269.00 K | SHL dew Pc = 3.224 bar
# T=270.00 K | SHL dew Pc = 5.926 bar
# T=271.00 K | SHL dew Pc = 8.598 bar
# T=272.00 K | SHL dew Pc = 11.240 bar
# T=273.00 K | SHL dew Pc = 13.854 bar
# T=274.00 K | SHL dew Pc = 16.439 bar
# T=275.00 K | SHL dew Pc = 18.996 bar
# T=276.00 K | SHL dew Pc = 21.526 bar
# T=277.00 K | SHL dew Pc = 24.028 bar
# T=278.00 K | SHL dew Pc = 26.505 bar
# T=279.00 K | SHL dew Pc = 28.955 bar
# T=280.00 K | SHL dew Pc = 31.380 bar
# T=281.00 K | SHL dew Pc = 33.781 bar
# T=282.00 K | SHL dew Pc = 36.157 bar
# T=283.00 K | SHL dew Pc = 38.511 bar
# T=284.00 K | SHL dew Pc = 40.842 bar
# T=286.00 K | SHL dew Pc = 45.442 bar
# T=287.00 K | SHL dew Pc = 47.712 bar
# T=288.00 K | SHL dew Pc = 49.964 bar
# T=289.00 K | SHL dew Pc = 52.200 bar
# T=290.00 K | SHL dew Pc = 54.422 bar
# T=291.00 K | SHL dew Pc = 56.631 bar
# T=292.00 K | SHL dew Pc = 58.830 bar
# T=293.00 K | SHL dew Pc = 61.024 bar
# T=294.00 K | SHL dew Pc = 63.217 bar
# T=295.00 K | SHL dew Pc = 65.416 bar
# T=296.00 K | SHL dew Pc = 67.632 bar
# T=297.00 K | SHL dew Pc = 69.881 bar
# T=298.00 K | SHL dew Pc = 72.197 bar
# T=299.00 K | SHL dew Pc = 74.651 bar

# %%
# --- choose which surface tension to use ---
GAMMA_KEY = "gamma_Parachor_mN_m"  # or "gamma_WSD_mN_m"

# --- choose which side to compute ---
SIDE = "bubble"      # <<< change to "bubble" or "dew" here
# --------------------------------------

scl_points = []

for rec in results_all:
    T_K = rec["T_K"]
    keyed = {s["point_type"]: s for s in rec["samples"]}

    # pick only the chosen side
    s = keyed.get(SIDE)
    if s is None:
        print(f"[skip] T={T_K:.2f} K | missing {SIDE} sample")
        continue

    # Extract needed fields
    Psat_Pa   = s["P_bar"] * 1e5
    gamma_N_m = s[GAMMA_KEY] * 1e-3
    rho_L     = s["rho_liq_kg_per_m3"]
    rho_g     = s["rho_vap_kg_per_m3"]
    x_list    = s["x"]
    y_list    = s["y"]

    # Sanity checks
    if gamma_N_m <= 0.0:
        print(f"[skip] T={T_K:.2f} K | gamma<=0 ({gamma_N_m:.3e})")
        continue
    if rho_L <= 0.0 or rho_g <= 0.0:
        print(f"[skip] T={T_K:.2f} K | invalid densities")
        continue
    if abs(sum(x_list) - 1.0) > 1e-8 or abs(sum(y_list) - 1.0) > 1e-8:
        print(f"[skip] T={T_K:.2f} K | composition sum error")
        continue

    scl_points.append({
        "T_K": T_K,
        "Psat_Pa": Psat_Pa,
        "gamma_N_m": gamma_N_m,
        "rho_L": rho_L,
        "rho_g": rho_g,
        "x_list": x_list,
        "y_list": y_list,
        "meta": {"point_type": SIDE, "P_bar": s["P_bar"]},
    })

# --- constants ---
M_CO2, M_N2 = 44.00985e-3, 28.0134e-3
M_list = [M_CO2, M_N2]
Jcrit = 1e12

# --- run SCL ---
def run_scl(points, label):
    results = []
    for row in points:
        try:
            scl = SCLMixture(
                Jcrit=Jcrit,
                Psat=row["Psat_Pa"],
                T=row["T_K"],
                gamma=row["gamma_N_m"],
                rho_L=row["rho_L"],
                rho_g=row["rho_g"],
                M_list=M_list,
                x_list=row["x_list"],
                y_list=row["y_list"],
            )
            Pc, rc, lnS = scl.compute()
            results.append({"T_K": row["T_K"], "Pc_bar": Pc/1e5, "rc_m": rc, "lnS": lnS})
        except ValueError as e:
            print(f"[skip] T={row['T_K']:.2f} K, {label:5s} | {e}")
            continue
    return results

scl_results = run_scl(scl_points, SIDE)

# --- save results ---
import csv
csv_filename = f"SCL_CO2_N2_{SIDE}.csv"

with open(csv_filename, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["T_K", "Pc_bar"])  # header row
    for r in scl_results:
        print(f"T={r['T_K']:.2f} K | SCL {SIDE} Pc = {r['Pc_bar']:.3f} bar")
        writer.writerow([r["T_K"], r["Pc_bar"]])
# Out:
# [skip] T=259.00 K | gamma<=0 (0.000e+00)
# [skip] T=260.00 K | gamma<=0 (0.000e+00)
# [skip] T=261.00 K | gamma<=0 (0.000e+00)
# [skip] T=262.00 K | gamma<=0 (0.000e+00)
# [skip] T=263.00 K | gamma<=0 (0.000e+00)
# [skip] T=264.00 K | gamma<=0 (0.000e+00)
# [skip] T=265.00 K | gamma<=0 (0.000e+00)
# [skip] T=266.00 K | gamma<=0 (0.000e+00)
# [skip] T=292.00 K | gamma<=0 (0.000e+00)
# [skip] T=293.00 K | gamma<=0 (0.000e+00)
# [skip] T=299.00 K | gamma<=0 (0.000e+00)
# T=220.00 K | SCL bubble Pc = 54.445 bar
# T=221.00 K | SCL bubble Pc = 54.103 bar
# T=222.00 K | SCL bubble Pc = 53.785 bar
# T=223.00 K | SCL bubble Pc = 53.490 bar
# T=224.00 K | SCL bubble Pc = 53.218 bar
# T=225.00 K | SCL bubble Pc = 52.969 bar
# T=226.00 K | SCL bubble Pc = 52.741 bar
# T=227.00 K | SCL bubble Pc = 52.535 bar
# T=228.00 K | SCL bubble Pc = 52.351 bar
# T=229.00 K | SCL bubble Pc = 52.187 bar
# T=230.00 K | SCL bubble Pc = 52.045 bar
# T=231.00 K | SCL bubble Pc = 51.923 bar
# T=232.00 K | SCL bubble Pc = 51.821 bar
# T=233.00 K | SCL bubble Pc = 51.740 bar
# T=234.00 K | SCL bubble Pc = 51.678 bar
# T=235.00 K | SCL bubble Pc = 51.636 bar
# T=236.00 K | SCL bubble Pc = 51.613 bar
# T=237.00 K | SCL bubble Pc = 51.609 bar
# T=238.00 K | SCL bubble Pc = 51.625 bar
# T=239.00 K | SCL bubble Pc = 51.659 bar
# T=240.00 K | SCL bubble Pc = 51.712 bar
# T=241.00 K | SCL bubble Pc = 51.783 bar
# T=242.00 K | SCL bubble Pc = 51.873 bar
# T=243.00 K | SCL bubble Pc = 51.981 bar
# T=244.00 K | SCL bubble Pc = 52.107 bar
# T=245.00 K | SCL bubble Pc = 52.251 bar
# T=246.00 K | SCL bubble Pc = 52.413 bar
# T=247.00 K | SCL bubble Pc = 52.593 bar
# T=248.00 K | SCL bubble Pc = 52.790 bar
# T=249.00 K | SCL bubble Pc = 53.005 bar
# T=250.00 K | SCL bubble Pc = 53.237 bar
# T=251.00 K | SCL bubble Pc = 51.929 bar
# T=252.00 K | SCL bubble Pc = 52.210 bar
# T=253.00 K | SCL bubble Pc = 52.509 bar
# T=254.00 K | SCL bubble Pc = 52.824 bar
# T=255.00 K | SCL bubble Pc = 53.156 bar
# T=256.00 K | SCL bubble Pc = 53.505 bar
# T=257.00 K | SCL bubble Pc = 53.870 bar
# T=258.00 K | SCL bubble Pc = 54.252 bar
# T=267.00 K | SCL bubble Pc = 58.439 bar
# T=268.00 K | SCL bubble Pc = 58.987 bar
# T=269.00 K | SCL bubble Pc = 59.552 bar
# T=270.00 K | SCL bubble Pc = 60.134 bar
# T=271.00 K | SCL bubble Pc = 60.732 bar
# T=272.00 K | SCL bubble Pc = 61.346 bar
# T=273.00 K | SCL bubble Pc = 61.978 bar
# T=274.00 K | SCL bubble Pc = 62.626 bar
# T=275.00 K | SCL bubble Pc = 63.290 bar
# T=276.00 K | SCL bubble Pc = 63.971 bar
# T=277.00 K | SCL bubble Pc = 64.668 bar
# T=278.00 K | SCL bubble Pc = 65.381 bar
# T=279.00 K | SCL bubble Pc = 66.110 bar
# T=280.00 K | SCL bubble Pc = 66.855 bar
# T=281.00 K | SCL bubble Pc = 67.616 bar
# T=282.00 K | SCL bubble Pc = 68.393 bar
# T=283.00 K | SCL bubble Pc = 69.184 bar
# T=284.00 K | SCL bubble Pc = 69.989 bar
# T=285.00 K | SCL bubble Pc = 70.809 bar
# T=286.00 K | SCL bubble Pc = 71.641 bar
# T=287.00 K | SCL bubble Pc = 72.485 bar
# T=288.00 K | SCL bubble Pc = 73.340 bar
# T=289.00 K | SCL bubble Pc = 74.204 bar
# T=290.00 K | SCL bubble Pc = 75.074 bar
# T=291.00 K | SCL bubble Pc = 75.947 bar
# T=294.00 K | SCL bubble Pc = 78.542 bar
# T=295.00 K | SCL bubble Pc = 79.370 bar
# T=296.00 K | SCL bubble Pc = 80.157 bar
# T=297.00 K | SCL bubble Pc = 80.875 bar
# T=298.00 K | SCL bubble Pc = 81.494 bar
