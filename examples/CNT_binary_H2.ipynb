# %%
from parachorpy import parachor as IFT
import numpy as np, pandas as pd, csv, os
from ctREFPROP.ctREFPROP import REFPROPFunctionLibrary
import matplotlib.pyplot as plt
from CNT_BINARY import SHLMixture, SCLMixture
from math import isnan

# %%
if __name__ == '__main__':
    
    json_files  = ["Mulero_2012.json"]
    model       = IFT.InterfacialTension(json_files)
    model.ctREFPROP_init('~/Software/REFPROP_BETA/REFPROP-cmake/build', gerg_enable=1)

    MIXTURE   = "CO2;Hydrogen"
    z         = [0.95, 0.05]
    T_list    = np.arange(220, 304, 1).tolist()
    kij       = 0.0
    phi_ij    = 1.0
        
    
results_all = []

for T in T_list:
    result = model.TP_DIAGRAM(MIXTURE, z, T, verbose=False)

    # tiny tolerance to avoid numerical issues exactly at phase limits
    tol_frac = 0.000005
    P_bub = result['bubble']['P_bar']
    P_dew = result['dew']['P_bar']

    # evaluate at both endpoints (tweaked by tol)
    PRESSURES = np.array([
        P_bub * (1.0 - tol_frac),  # bubble-side
        P_dew * (1.0 + tol_frac),  # dew-side
    ])

    print(f"T={T:.2f} K | evaluating at P_bubble={PRESSURES[0]:.6f} bar, P_dew={PRESSURES[1]:.6f} bar")

    Pbar, gamma_Parachor, gamma_WSD, x, y, rhol, rhov, mml, mmv = \
        model.gamma_TP(MIXTURE, z, T, PRESSURES, kij, phi_ij)

    
    # per-temperature envelope snapshot
    envelope = {
        "bubble": {
            "P_bar": round(P_bub, 6),
            "x": [round(v, 6) for v in result['bubble']['x']],
            "y": [round(v, 6) for v in result['bubble']['y']],
        },
        "dew": {
            "P_bar": round(P_dew, 6),
            "x": [round(v, 6) for v in result['dew']['x']],
            "y": [round(v, 6) for v in result['dew']['y']],
        },
        "Tc_K": round(result["Tc"], 4),
    }

    # build labeled rows for the two pressures
    samples = []
    for P, s1, s2, xl, yv, ml, mv, rhol_i, rhog_i in zip(Pbar, gamma_Parachor, gamma_WSD, x, y, mml, mmv, rhol, rhov):
        # decide which endpoint this is closest to
        point_type = "bubble" if abs(P - P_bub) <= abs(P - P_dew) else "dew"

        samples.append({
            "point_type": point_type,                      # "bubble" or "dew"
            "T_K": round(T, 4),
            "P_bar": round(P, 6),
            "gamma_Parachor_mN_m": round(s1, 8),
            "gamma_WSD_mN_m": round(s2, 8),
            "x": [round(v, 6) for v in xl],
            "y": [round(v, 6) for v in yv],
            "M_liq_kg_per_mol": round(ml, 8),
            "M_vap_kg_per_mol": round(mv, 8),
            "rho_liq_kg_per_m3": round(rhol_i, 6),
            "rho_vap_kg_per_m3": round(rhog_i, 6),
        })

    # one record per temperature with both labeled points
    results_all.append({
        "mixture": MIXTURE,
        "z": z,
        "kij": kij,
        "phi_ij": phi_ij,
        "T_K": round(T, 4),
        "envelope": envelope,   # bubble/dew data & Tc for this T
        "samples": samples,     # two rows: bubble & dew
    })

    # (optional) your printout
    print("\n--- Results ---")
    print(f"Temperature           : {T:.4f} K")
    print(f"Critical Temperature  : {envelope['Tc_K']:.4f} K")
    print("Pbar:", [round(float(v), 6) for v in Pbar[:2]])
    print("gamma_Parachor_mN_m:", [round(float(v), 8) for v in gamma_Parachor[:2]])
    print("gamma_WSD_mN_m:", [round(float(v), 8) for v in gamma_WSD[:2]])
    print("x:", [[round(float(e), 6) for e in arr] for arr in x[:2]])
    print("y:", [[round(float(e), 6) for e in arr] for arr in y[:2]])
    print("M_liq:", [round(float(v), 8) for v in mml[:2]])
    print("M_vap:", [round(float(v), 8) for v in mmv[:2]])
    print("rho_liq:", [round(float(v), 6) for v in rhol[:2]])
    print("rho_vap:", [round(float(v), 6) for v in rhov[:2]])
    print("--- End ---\n")
# Out:
# REFPROP version = 10.0.2.01
# GERG-2008 model = Enabled
# T=220.00 K | evaluating at P_bubble=-99999400.000500 bar, P_dew=6.342288 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 220.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [-99999400.0005, 6.342288]
# gamma_Parachor_mN_m: [0.0, 0.0]
# gamma_WSD_mN_m: [0.0, 0.0]
# x: [[0.95, 0.05], [0.95, 0.05]]
# y: [[0.95, 0.05], [0.95, 0.05]]
# M_liq: [41.909819, 41.909819]
# M_vap: [41.909819, 41.909819]
# rho_liq: [-9999990.0, -9999990.0]
# rho_vap: [-9999990.0, -9999990.0]
# --- End ---
#
# T=221.00 K | evaluating at P_bubble=-99999400.000500 bar, P_dew=6.613950 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 221.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [-99999400.0005, 6.61395]
# gamma_Parachor_mN_m: [0.0, 0.0]
# gamma_WSD_mN_m: [0.0, 0.0]
# x: [[0.95, 0.05], [0.95, 0.05]]
# y: [[0.95, 0.05], [0.95, 0.05]]
# M_liq: [41.909819, 41.909819]
# M_vap: [41.909819, 41.909819]
# rho_liq: [-9999990.0, -9999990.0]
# rho_vap: [-9999990.0, -9999990.0]
# --- End ---
#
# T=222.00 K | evaluating at P_bubble=-99999400.000500 bar, P_dew=6.894328 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 222.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [-99999400.0005, 6.894328]
# gamma_Parachor_mN_m: [0.0, 0.0]
# gamma_WSD_mN_m: [0.0, 0.0]
# x: [[0.95, 0.05], [0.95, 0.05]]
# y: [[0.95, 0.05], [0.95, 0.05]]
# M_liq: [41.909819, 41.909819]
# M_vap: [41.909819, 41.909819]
# rho_liq: [-9999990.0, -9999990.0]
# rho_vap: [-9999990.0, -9999990.0]
# --- End ---
#
# T=223.00 K | evaluating at P_bubble=443.587854 bar, P_dew=7.183604 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 223.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [443.587854, 7.183604]
# gamma_Parachor_mN_m: [3.32819354, 14.982604]
# gamma_WSD_mN_m: [13.26020038, 15.00297068]
# x: [[1.0, 0.0], [0.999888, 0.000112]]
# y: [[0.196714, 0.803286], [0.949996, 0.050004]]
# M_liq: [44.00948426, 44.00478574]
# M_vap: [10.276632, 41.90964211]
# rho_liq: [1232.857005, 1154.928277]
# rho_vap: [194.56477, 17.873644]
# --- End ---
#
# T=224.00 K | evaluating at P_bubble=376.601014 bar, P_dew=7.481957 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 224.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [376.601014, 7.481957]
# gamma_Parachor_mN_m: [4.41863964, 14.7502325]
# gamma_WSD_mN_m: [14.01303228, 14.77119147]
# x: [[1.0, 0.0], [0.999879, 0.000121]]
# y: [[0.160232, 0.839768], [0.949996, 0.050004]]
# M_liq: [44.00949248, 44.00443036]
# M_vap: [8.74460055, 41.9096428]
# rho_liq: [1220.35724, 1151.197233]
# rho_vap: [145.367064, 18.586683]
# --- End ---
#
# T=225.00 K | evaluating at P_bubble=339.283557 bar, P_dew=7.789570 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 225.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [339.283557, 7.78957]
# gamma_Parachor_mN_m: [5.0057883, 14.51856326]
# gamma_WSD_mN_m: [14.11885679, 14.54012351]
# x: [[1.0, 0.0], [0.99987, 0.00013]]
# y: [[0.148917, 0.851083], [0.949996, 0.050004]]
# M_liq: [44.00949523, 44.00405158]
# M_vap: [8.269459, 41.9096435]
# rho_liq: [1211.751552, 1147.446366]
# rho_vap: [126.333243, 19.321956]
# --- End ---
#
# T=226.00 K | evaluating at P_bubble=312.131650 bar, P_dew=8.106628 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 226.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [312.13165, 8.106628]
# gamma_Parachor_mN_m: [5.42877306, 14.28760255]
# gamma_WSD_mN_m: [14.07483293, 14.30977299]
# x: [[1.0, 0.0], [0.999861, 0.000139]]
# y: [[0.143722, 0.856278], [0.949996, 0.050004]]
# M_liq: [44.00949668, 44.00364807]
# M_vap: [8.05127455, 41.90964421]
# rho_liq: [1204.468158, 1143.675114]
# rho_vap: [114.780165, 20.080015]
# --- End ---
#
# T=227.00 K | evaluating at P_bubble=290.571842 bar, P_dew=8.433315 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 227.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [290.571842, 8.433315]
# gamma_Parachor_mN_m: [5.75927991, 14.05735677]
# gamma_WSD_mN_m: [13.96503408, 14.08014628]
# x: [[1.0, 0.0], [0.99985, 0.00015]]
# y: [[0.141415, 0.858585], [0.949996, 0.050004]]
# M_liq: [44.00949756, 44.00321843]
# M_vap: [7.9544083, 41.90964492]
# rho_liq: [1197.903876, 1139.882895]
# rho_vap: [106.730823, 20.861424]
# --- End ---
#
# T=228.00 K | evaluating at P_bubble=272.666965 bar, P_dew=8.769819 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 228.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [272.666965, 8.769819]
# gamma_Parachor_mN_m: [6.02686656, 13.8278325]
# gamma_WSD_mN_m: [13.819555, 13.85124988]
# x: [[1.0, 0.0], [0.99984, 0.00016]]
# y: [[0.140827, 0.859173], [0.949996, 0.050004]]
# M_liq: [44.00949815, 44.00276118]
# M_vap: [7.92972257, 41.90964565]
# rho_liq: [1191.803696, 1136.069108]
# rho_vap: [100.722138, 21.666766]
# --- End ---
#
# T=229.00 K | evaluating at P_bubble=257.364926 bar, P_dew=9.116329 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 229.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [257.364926, 9.116329]
# gamma_Parachor_mN_m: [6.24758706, 13.59903645]
# gamma_WSD_mN_m: [13.65255574, 13.62309048]
# x: [[1.0, 0.0], [0.999828, 0.000172]]
# y: [[0.141399, 0.858601], [0.949996, 0.050004]]
# M_liq: [44.00949857, 44.00227477]
# M_vap: [7.95372589, 41.90964638]
# rho_liq: [1186.028505, 1132.233131]
# rho_vap: [96.043135, 22.496637]
# --- End ---
#
# T=230.00 K | evaluating at P_bubble=244.027199 bar, P_dew=9.473036 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 230.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [244.027199, 9.473036]
# gamma_Parachor_mN_m: [6.43126313, 13.37097555]
# gamma_WSD_mN_m: [13.47168364, 13.3956749]
# x: [[1.0, 0.0], [0.999816, 0.000184]]
# y: [[0.142823, 0.857177], [0.949996, 0.050004]]
# M_liq: [44.00949887, 44.00175757]
# M_vap: [8.01354501, 41.90964713]
# rho_liq: [1180.493703, 1128.374317]
# rho_vap: [92.298143, 23.351655]
# --- End ---
#
# T=231.00 K | evaluating at P_bubble=232.241875 bar, P_dew=9.840132 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 231.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [232.241875, 9.840132]
# gamma_Parachor_mN_m: [6.58427392, 13.14365687]
# gamma_WSD_mN_m: [13.28144886, 13.16901019]
# x: [[1.0, 0.0], [0.999803, 0.000197]]
# y: [[0.144917, 0.855083], [0.949996, 0.050004]]
# M_liq: [44.0094991, 44.00120786]
# M_vap: [8.10148667, 41.90964788]
# rho_liq: [1175.145068, 1124.491996]
# rho_vap: [89.248503, 24.232452]
# --- End ---
#
# T=232.00 K | evaluating at P_bubble=221.709702 bar, P_dew=10.217810 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 232.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [221.709702, 10.21781]
# gamma_Parachor_mN_m: [6.71142943, 12.91708769]
# gamma_WSD_mN_m: [13.08476441, 12.94310355]
# x: [[1.0, 0.0], [0.999789, 0.000211]]
# y: [[0.147561, 0.852439], [0.949996, 0.050004]]
# M_liq: [44.00949927, 44.00062385]
# M_vap: [8.21250024, 41.90964865]
# rho_liq: [1169.942509, 1120.585474]
# rho_vap: [86.733158, 25.139683]
# --- End ---
#
# T=233.00 K | evaluating at P_bubble=212.212295 bar, P_dew=10.606267 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 233.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [212.212295, 10.606267]
# gamma_Parachor_mN_m: [6.81634058, 12.69127549]
# gamma_WSD_mN_m: [12.88357221, 12.71796238]
# x: [[1.0, 0.0], [0.999774, 0.000226]]
# y: [[0.150673, 0.849327], [0.949996, 0.050004]]
# M_liq: [44.00949941, 44.00000364]
# M_vap: [8.3431835, 41.90964942]
# rho_liq: [1164.856573, 1116.654031]
# rho_vap: [84.641129, 26.074021]
# --- End ---
#
# T=234.00 K | evaluating at P_bubble=203.595393 bar, P_dew=11.005701 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 234.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [203.595393, 11.005701]
# gamma_Parachor_mN_m: [6.90157576, 12.46622795]
# gamma_WSD_mN_m: [12.67918904, 12.49359431]
# x: [[1.0, 0.0], [0.999758, 0.000242]]
# y: [[0.154198, 0.845802], [0.949996, 0.050004]]
# M_liq: [44.00949952, 43.99934525]
# M_vap: [8.4911994, 41.90965021]
# rho_liq: [1159.867004, 1112.696917]
# rho_vap: [82.897036, 27.036162]
# --- End ---
#
# T=235.00 K | evaluating at P_bubble=195.727494 bar, P_dew=11.416310 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 235.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [195.727494, 11.41631]
# gamma_Parachor_mN_m: [6.96947139, 12.24195297]
# gamma_WSD_mN_m: [12.47259433, 12.27000716]
# x: [[1.0, 0.0], [0.999742, 0.000258]]
# y: [[0.158093, 0.841907], [0.949996, 0.050004]]
# M_liq: [44.00949961, 43.99864657]
# M_vap: [8.65479643, 41.909651]
# rho_liq: [1154.95563, 1108.713355]
# rho_vap: [81.440493, 28.026825]
# --- End ---
#
# T=236.00 K | evaluating at P_bubble=188.508628 bar, P_dew=11.838297 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 236.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [188.508628, 11.838297]
# gamma_Parachor_mN_m: [7.02184692, 12.01845866]
# gamma_WSD_mN_m: [12.2644947, 12.04720898]
# x: [[1.0, 0.0], [0.999724, 0.000276]]
# y: [[0.16233, 0.83767], [0.949996, 0.050004]]
# M_liq: [44.00949968, 43.99790542]
# M_vap: [8.83269987, 41.90965181]
# rho_liq: [1150.108755, 1104.702538]
# rho_vap: [80.227327, 29.046751]
# --- End ---
#
# T=237.00 K | evaluating at P_bubble=181.857888 bar, P_dew=12.271866 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 237.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [181.857888, 12.271866]
# gamma_Parachor_mN_m: [7.0602315, 11.79575338]
# gamma_WSD_mN_m: [12.05542118, 11.82520804]
# x: [[1.0, 0.0], [0.999705, 0.000295]]
# y: [[0.166884, 0.833116], [0.949996, 0.050004]]
# M_liq: [44.00949973, 43.99711947]
# M_vap: [9.02394433, 41.90965263]
# rho_liq: [1145.315163, 1100.663625]
# rho_vap: [79.22323, 30.096709]
# --- End ---
#
# T=238.00 K | evaluating at P_bubble=175.706614 bar, P_dew=12.717222 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 238.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [175.706614, 12.717222]
# gamma_Parachor_mN_m: [7.08598177, 11.57384575]
# gamma_WSD_mN_m: [11.84578429, 11.60401289]
# x: [[1.0, 0.0], [0.999685, 0.000315]]
# y: [[0.171738, 0.828262], [0.949996, 0.050004]]
# M_liq: [44.00949978, 43.99628628]
# M_vap: [9.22778907, 41.90965346]
# rho_liq: [1140.565015, 1096.595742]
# rho_vap: [78.400234, 31.177492]
# --- End ---
#
# T=239.00 K | evaluating at P_bubble=170.004488 bar, P_dew=13.174573 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 239.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [170.004488, 13.174573]
# gamma_Parachor_mN_m: [7.10010865, 11.35274462]
# gamma_WSD_mN_m: [11.63588954, 11.3836323]
# x: [[1.0, 0.0], [0.999664, 0.000336]]
# y: [[0.176878, 0.823122], [0.949996, 0.050004]]
# M_liq: [44.00949982, 43.9954033]
# M_vap: [9.44364492, 41.9096543]
# rho_liq: [1135.851533, 1092.497981]
# rho_vap: [77.73853, 32.289925]
# --- End ---
#
# T=240.00 K | evaluating at P_bubble=164.701972 bar, P_dew=13.644130 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 240.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [164.701972, 13.64413]
# gamma_Parachor_mN_m: [7.10366889, 11.13245914]
# gamma_WSD_mN_m: [11.42599163, 11.16407534]
# x: [[1.0, 0.0], [0.999642, 0.000358]]
# y: [[0.182294, 0.817706], [0.949996, 0.050004]]
# M_liq: [44.00949985, 43.99446782]
# M_vap: [9.67104853, 41.90965515]
# rho_liq: [1131.167283, 1088.369393]
# rho_vap: [77.219288, 33.434858]
# --- End ---
#
# T=241.00 K | evaluating at P_bubble=159.759569 bar, P_dew=14.126104 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 241.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [159.759569, 14.126104]
# gamma_Parachor_mN_m: [7.09753108, 10.91299873]
# gamma_WSD_mN_m: [11.21628855, 10.94535133]
# x: [[1.0, 0.0], [0.999618, 0.000382]]
# y: [[0.187975, 0.812025], [0.949996, 0.050004]]
# M_liq: [44.00949988, 43.99347699]
# M_vap: [9.90962105, 41.90965602]
# rho_liq: [1126.506404, 1084.208993]
# rho_vap: [76.82802, 34.613178]
# --- End ---
#
# T=242.00 K | evaluating at P_bubble=155.143409 bar, P_dew=14.620712 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 242.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [155.143409, 14.620712]
# gamma_Parachor_mN_m: [7.08246856, 10.69437313]
# gamma_WSD_mN_m: [11.00693973, 10.72746992]
# x: [[1.0, 0.0], [0.999593, 0.000407]]
# y: [[0.193914, 0.806086], [0.949996, 0.050004]]
# M_liq: [44.0094999, 43.99242782]
# M_vap: [10.15905034, 41.90965689]
# rho_liq: [1121.863749, 1080.01575]
# rho_vap: [76.552717, 35.825801]
# --- End ---
#
# T=243.00 K | evaluating at P_bubble=150.822542 bar, P_dew=15.128170 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 243.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [150.822542, 15.12817]
# gamma_Parachor_mN_m: [7.05921311, 10.47659236]
# gamma_WSD_mN_m: [10.79807715, 10.51044104]
# x: [[1.0, 0.0], [0.999567, 0.000433]]
# y: [[0.200107, 0.799893], [0.949996, 0.050004]]
# M_liq: [44.00949992, 43.99131714]
# M_vap: [10.41908783, 41.90965778]
# rho_liq: [1117.234324, 1075.788593]
# rho_vap: [76.382679, 37.073681]
# --- End ---
#
# T=244.00 K | evaluating at P_bubble=146.775265 bar, P_dew=15.648700 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 244.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [146.775265, 15.6487]
# gamma_Parachor_mN_m: [7.02830182, 10.2596668]
# gamma_WSD_mN_m: [10.5898027, 10.29427497]
# x: [[1.0, 0.0], [0.999539, 0.000461]]
# y: [[0.206545, 0.793455], [0.949996, 0.050004]]
# M_liq: [44.00949993, 43.99014161]
# M_vap: [10.68946804, 41.90965868]
# rho_liq: [1112.61499, 1071.5264]
# rho_vap: [76.310927, 38.357811]
# --- End ---
#
# T=245.00 K | evaluating at P_bubble=142.977116 bar, P_dew=16.182524 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 245.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [142.977116, 16.182524]
# gamma_Parachor_mN_m: [6.9903512, 10.04360718]
# gamma_WSD_mN_m: [10.38220792, 10.07898231]
# x: [[1.0, 0.0], [0.999509, 0.000491]]
# y: [[0.213226, 0.786774], [0.949996, 0.050004]]
# M_liq: [44.00949994, 43.98889773]
# M_vap: [10.97000222, 41.9096596]
# rho_liq: [1108.001506, 1067.228002]
# rho_vap: [76.329463, 39.679221]
# --- End ---
#
# T=246.00 K | evaluating at P_bubble=139.408493 bar, P_dew=16.729869 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 246.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [139.408493, 16.729869]
# gamma_Parachor_mN_m: [6.94587592, 9.82842458]
# gamma_WSD_mN_m: [10.17536696, 9.86457405]
# x: [[1.0, 0.0], [0.999478, 0.000522]]
# y: [[0.220143, 0.779857], [0.949996, 0.050004]]
# M_liq: [44.00949995, 43.98758177]
# M_vap: [11.26049876, 41.90966052]
# rho_liq: [1103.390502, 1062.892176]
# rho_vap: [76.432206, 41.038986]
# --- End ---
#
# T=247.00 K | evaluating at P_bubble=136.052049 bar, P_dew=17.290964 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 247.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [136.052049, 17.290964]
# gamma_Parachor_mN_m: [6.89534717, 9.61413048]
# gamma_WSD_mN_m: [9.96934229, 9.65106153]
# x: [[1.0, 0.0], [0.999445, 0.000555]]
# y: [[0.227294, 0.772706], [0.949996, 0.050004]]
# M_liq: [44.00949996, 43.9861898]
# M_vap: [11.5607782, 41.90966146]
# rho_liq: [1098.778876, 1058.517643]
# rho_vap: [76.613969, 42.438226]
# --- End ---
#
# T=248.00 K | evaluating at P_bubble=132.890753 bar, P_dew=17.866042 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 248.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [132.890753, 17.866042]
# gamma_Parachor_mN_m: [6.83923277, 9.40073676]
# gamma_WSD_mN_m: [9.7641885, 9.4384565]
# x: [[1.0, 0.0], [0.99941, 0.00059]]
# y: [[0.234674, 0.765326], [0.949996, 0.050004]]
# M_liq: [44.00949997, 43.98471767]
# M_vap: [11.87069524, 41.90966242]
# rho_liq: [1094.163286, 1054.103064]
# rho_vap: [76.869653, 43.87811]
# --- End ---
#
# T=249.00 K | evaluating at P_bubble=129.914465 bar, P_dew=18.455339 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 249.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [129.914465, 18.455339]
# gamma_Parachor_mN_m: [6.77785074, 9.18825575]
# gamma_WSD_mN_m: [9.55994872, 9.22677113]
# x: [[1.0, 0.0], [0.999373, 0.000627]]
# y: [[0.242278, 0.757722], [0.949996, 0.050004]]
# M_liq: [44.00949998, 43.983161]
# M_vap: [12.19000177, 41.90966339]
# rho_liq: [1089.54208, 1049.647038]
# rho_vap: [77.196892, 45.359858]
# --- End ---
#
# T=250.00 K | evaluating at P_bubble=127.108748 bar, P_dew=19.059094 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 250.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [127.108748, 19.059094]
# gamma_Parachor_mN_m: [6.71161549, 8.9767002]
# gamma_WSD_mN_m: [9.35666491, 9.01601805]
# x: [[1.0, 0.0], [0.999334, 0.000666]]
# y: [[0.250102, 0.749898], [0.949996, 0.050004]]
# M_liq: [44.00949998, 43.98151512]
# M_vap: [12.51854787, 41.90966437]
# rho_liq: [1084.912132, 1045.148096]
# rho_vap: [77.591544, 46.884744]
# --- End ---
#
# T=251.00 K | evaluating at P_bubble=124.462544 bar, P_dew=19.677551 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 251.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [124.462544, 19.677551]
# gamma_Parachor_mN_m: [6.64086713, 8.76608339]
# gamma_WSD_mN_m: [9.15437235, 8.80621031]
# x: [[1.0, 0.0], [0.999292, 0.000708]]
# y: [[0.258141, 0.741859], [0.949996, 0.050004]]
# M_liq: [44.00949998, 43.97977511]
# M_vap: [12.85613759, 41.90966536]
# rho_liq: [1080.271049, 1040.604697]
# rho_vap: [78.050775, 48.454104]
# --- End ---
#
# T=252.00 K | evaluating at P_bubble=121.965845 bar, P_dew=20.310958 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 252.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [121.965845, 20.310958]
# gamma_Parachor_mN_m: [6.5659244, 8.55641906]
# gamma_WSD_mN_m: [8.95310169, 8.59736151]
# x: [[1.0, 0.0], [0.999248, 0.000752]]
# y: [[0.26639, 0.73361], [0.949996, 0.050004]]
# M_liq: [44.00949999, 43.97793574]
# M_vap: [13.20257954, 41.90966637]
# rho_liq: [1075.616535, 1036.015224]
# rho_vap: [78.572163, 50.069335]
# --- End ---
#
# T=253.00 K | evaluating at P_bubble=119.609659 bar, P_dew=20.959567 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 253.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [119.609659, 20.959567]
# gamma_Parachor_mN_m: [6.48708104, 8.34772152]
# gamma_WSD_mN_m: [8.75288135, 8.38948574]
# x: [[1.0, 0.0], [0.999202, 0.000798]]
# y: [[0.274846, 0.725154], [0.949996, 0.050004]]
# M_liq: [44.00949999, 43.97599148]
# M_vap: [13.55764929, 41.90966739]
# rho_liq: [1070.946405, 1031.377978]
# rho_vap: [79.153608, 51.731901]
# --- End ---
#
# T=254.00 K | evaluating at P_bubble=117.385818 bar, P_dew=21.623634 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 254.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [117.385818, 21.623634]
# gamma_Parachor_mN_m: [6.4046132, 8.14000565]
# gamma_WSD_mN_m: [8.55373679, 8.18259764]
# x: [[1.0, 0.0], [0.999153, 0.000847]]
# y: [[0.283501, 0.716499], [0.949996, 0.050004]]
# M_liq: [44.00949999, 43.97393642]
# M_vap: [13.92111722, 41.90966843]
# rho_liq: [1066.258546, 1026.691171]
# rho_vap: [79.793321, 53.44334]
# --- End ---
#
# T=255.00 K | evaluating at P_bubble=115.286885 bar, P_dew=22.303422 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 255.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [115.286885, 22.303422]
# gamma_Parachor_mN_m: [6.31877737, 7.93328693]
# gamma_WSD_mN_m: [8.35569254, 7.97671244]
# x: [[1.0, 0.0], [0.999101, 0.000899]]
# y: [[0.29235, 0.70765], [0.949996, 0.050004]]
# M_liq: [44.00949999, 43.97176431]
# M_vap: [14.29271198, 41.90966949]
# rho_liq: [1061.550897, 1021.952924]
# rho_vap: [80.489713, 55.205269]
# --- End ---
#
# T=256.00 K | evaluating at P_bubble=113.306086 bar, P_dew=22.999197 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 256.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [113.306086, 22.999197]
# gamma_Parachor_mN_m: [6.22981929, 7.72758148]
# gamma_WSD_mN_m: [8.15876971, 7.77184599]
# x: [[1.0, 0.0], [0.999047, 0.000953]]
# y: [[0.301386, 0.698614], [0.949996, 0.050004]]
# M_liq: [44.00949999, 43.96946849]
# M_vap: [14.67218737, 41.90967056]
# rho_liq: [1056.82145, 1017.161257]
# rho_vap: [81.241502, 57.019385]
# --- End ---
#
# T=257.00 K | evaluating at P_bubble=111.437242 bar, P_dew=23.711231 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 257.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [111.437242, 23.711231]
# gamma_Parachor_mN_m: [6.13796396, 7.52290614]
# gamma_WSD_mN_m: [7.96299086, 7.56801479]
# x: [[1.0, 0.0], [0.998989, 0.001011]]
# y: [[0.310603, 0.689397], [0.949996, 0.050004]]
# M_liq: [44.0095, 43.96704185]
# M_vap: [15.05921255, 41.90967164]
# rho_liq: [1052.068232, 1012.31408]
# rho_vap: [82.047489, 58.887478]
# --- End ---
#
# T=258.00 K | evaluating at P_bubble=109.674706 bar, P_dew=24.439803 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 258.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [109.674706, 24.439803]
# gamma_Parachor_mN_m: [6.04342981, 7.31927843]
# gamma_WSD_mN_m: [7.76837536, 7.36523606]
# x: [[1.0, 0.0], [0.998928, 0.001072]]
# y: [[0.319992, 0.680008], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.96447682]
# M_vap: [15.45349409, 41.90967274]
# rho_liq: [1047.289301, 1007.409191]
# rho_vap: [82.906744, 60.811434]
# --- End ---
#
# T=259.00 K | evaluating at P_bubble=108.013311 bar, P_dew=25.185197 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 259.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [108.013311, 25.185197]
# gamma_Parachor_mN_m: [5.94642007, 7.1167167]
# gamma_WSD_mN_m: [7.57494347, 7.16352773]
# x: [[1.0, 0.0], [0.998863, 0.001137]]
# y: [[0.329545, 0.670455], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.9617653]
# M_vap: [15.8546772, 41.90967385]
# rho_liq: [1042.482732, 1002.444261]
# rho_vap: [83.818425, 62.793244]
# --- End ---
#
# T=260.00 K | evaluating at P_bubble=106.448319 bar, P_dew=25.947705 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 260.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [106.448319, 25.947705]
# gamma_Parachor_mN_m: [5.84712847, 6.91524012]
# gamma_WSD_mN_m: [7.38271484, 6.96290853]
# x: [[1.0, 0.0], [0.998795, 0.001205]]
# y: [[0.339254, 0.660746], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.95889867]
# M_vap: [16.26239059, 41.90967498]
# rho_liq: [1037.646616, 997.416826]
# rho_vap: [84.781826, 64.835014]
# --- End ---
#
# T=261.00 K | evaluating at P_bubble=104.975386 bar, P_dew=26.727627 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 261.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [104.975386, 26.727627]
# gamma_Parachor_mN_m: [5.74573872, 6.71486875]
# gamma_WSD_mN_m: [7.19170928, 6.76339805]
# x: [[1.0, 0.0], [0.998723, 0.001277]]
# y: [[0.349109, 0.650891], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.95586765]
# M_vap: [16.67622863, 41.90967613]
# rho_liq: [1032.779046, 992.324279]
# rho_vap: [85.796341, 66.93897]
# --- End ---
#
# T=262.00 K | evaluating at P_bubble=103.590518 bar, P_dew=27.525268 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 262.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [103.590518, 27.525268]
# gamma_Parachor_mN_m: [5.64242887, 6.5156236]
# gamma_WSD_mN_m: [7.00194573, 6.56501676]
# x: [[1.0, 0.0], [0.998647, 0.001353]]
# y: [[0.3591, 0.6409], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.95266233]
# M_vap: [17.09579148, 41.90967729]
# rho_liq: [1027.878115, 987.163855]
# rho_vap: [86.861498, 69.107474]
# --- End ---
#
# T=263.00 K | evaluating at P_bubble=102.290046 bar, P_dew=28.340945 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 263.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [102.290046, 28.340945]
# gamma_Parachor_mN_m: [5.53736453, 6.31752673]
# gamma_WSD_mN_m: [6.81344509, 6.36778609]
# x: [[1.0, 0.0], [0.998566, 0.001434]]
# y: [[0.369216, 0.630784], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.94927205]
# M_vap: [17.52059339, 41.90967847]
# rho_liq: [1022.941907, 981.932617]
# rho_vap: [87.976817, 71.343031]
# --- End ---
#
# T=264.00 K | evaluating at P_bubble=101.070461 bar, P_dew=29.174982 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 264.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [101.070461, 29.174982]
# gamma_Parachor_mN_m: [5.43070837, 6.12060129]
# gamma_WSD_mN_m: [6.62622782, 6.1717285]
# x: [[1.0, 0.0], [0.99848, 0.00152]]
# y: [[0.379445, 0.620555], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.94568536]
# M_vap: [17.95015033, 41.90967966]
# rho_liq: [1017.968436, 976.627447]
# rho_vap: [89.141857, 73.648304]
# --- End ---
#
# T=265.00 K | evaluating at P_bubble=99.928940 bar, P_dew=30.027712 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 265.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [99.92894, 30.027712]
# gamma_Parachor_mN_m: [5.32261568, 5.92487164]
# gamma_WSD_mN_m: [6.44031361, 5.97686758]
# x: [[1.0, 0.0], [0.99839, 0.00161]]
# y: [[0.389776, 0.610224], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.94188994]
# M_vap: [18.38398969, 41.90968087]
# rho_liq: [1012.955881, 971.245023]
# rho_vap: [90.356487, 76.02613]
# --- End ---
#
# T=266.00 K | evaluating at P_bubble=98.862444 bar, P_dew=30.899483 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 266.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [98.862444, 30.899483]
# gamma_Parachor_mN_m: [5.21323414, 5.7303634]
# gamma_WSD_mN_m: [6.25572523, 5.78322807]
# x: [[1.0, 0.0], [0.998294, 0.001706]]
# y: [[0.400195, 0.599805], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.93787247]
# M_vap: [18.82152123, 41.9096821]
# rho_liq: [1007.902193, 965.781804]
# rho_vap: [91.620263, 78.479532]
# --- End ---
#
# T=267.00 K | evaluating at P_bubble=97.868333 bar, P_dew=31.790651 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 267.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [97.868333, 31.790651]
# gamma_Parachor_mN_m: [5.10271184, 5.5371036]
# gamma_WSD_mN_m: [6.07248368, 5.59083601]
# x: [[1.0, 0.0], [0.998193, 0.001807]]
# y: [[0.41069, 0.58931], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.93361858]
# M_vap: [19.26222368, 41.90968334]
# rho_liq: [1002.805374, 960.234009]
# rho_vap: [92.932967, 81.01174]
# --- End ---
#
# T=268.00 K | evaluating at P_bubble=96.944162 bar, P_dew=32.701585 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 268.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [96.944162, 32.701585]
# gamma_Parachor_mN_m: [4.99119014, 5.34512078]
# gamma_WSD_mN_m: [5.8906114, 5.39971882]
# x: [[1.0, 0.0], [0.998086, 0.001914]]
# y: [[0.421246, 0.578754], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.9291127]
# M_vap: [19.70551913, 41.90968459]
# rho_liq: [997.663385, 954.597595]
# rho_vap: [94.294349, 83.626211]
# --- End ---
#
# T=269.00 K | evaluating at P_bubble=96.087665 bar, P_dew=33.632671 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 269.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [96.087665, 33.632671]
# gamma_Parachor_mN_m: [4.87880431, 5.1544451]
# gamma_WSD_mN_m: [5.71013198, 5.20990538]
# x: [[1.0, 0.0], [0.997972, 0.002028]]
# y: [[0.431849, 0.568151], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.92433796]
# M_vap: [20.15077477, 41.90968585]
# rho_liq: [992.474143, 948.868231]
# rho_vap: [95.704133, 86.326649]
# --- End ---
#
# T=270.00 K | evaluating at P_bubble=95.296742 bar, P_dew=34.584307 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 270.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [95.296742, 34.584307]
# gamma_Parachor_mN_m: [4.76568898, 4.96510853]
# gamma_WSD_mN_m: [5.53106877, 5.02142623]
# x: [[1.0, 0.0], [0.997851, 0.002149]]
# y: [[0.442484, 0.557516], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.91927599]
# M_vap: [20.59737763, 41.90968713]
# rho_liq: [987.235518, 943.041265]
# rho_vap: [97.162077, 89.117037]
# --- End ---
#
# T=271.00 K | evaluating at P_bubble=94.569392 bar, P_dew=35.556909 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 271.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [94.569392, 35.556909]
# gamma_Parachor_mN_m: [4.651975, 4.77714494]
# gamma_WSD_mN_m: [5.3534458, 4.83431362]
# x: [[1.0, 0.0], [0.997724, 0.002276]]
# y: [[0.453136, 0.546864], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.91390681]
# M_vap: [21.04468475, 41.90968842]
# rho_liq: [981.9453, 937.111696]
# rho_vap: [98.667891, 92.001658]
# --- End ---
#
# T=272.00 K | evaluating at P_bubble=93.903904 bar, P_dew=36.550912 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 272.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [93.903904, 36.550912]
# gamma_Parachor_mN_m: [4.53779107, 4.59059037]
# gamma_WSD_mN_m: [5.1772872, 4.64860172]
# x: [[1.0, 0.0], [0.997588, 0.002412]]
# y: [[0.463789, 0.536211], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.90820858]
# M_vap: [21.49206203, 41.90968971]
# rho_liq: [976.601301, 931.074133]
# rho_vap: [100.221365, 94.985135]
# --- End ---
#
# T=273.00 K | evaluating at P_bubble=93.298514 bar, P_dew=37.566771 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 273.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [93.298514, 37.566771]
# gamma_Parachor_mN_m: [4.42326519, 4.40548316]
# gamma_WSD_mN_m: [5.00261712, 4.46432679]
# x: [[1.0, 0.0], [0.997444, 0.002556]]
# y: [[0.474429, 0.525571], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.90215738]
# M_vap: [21.93888254, 41.909691]
# rho_liq: [971.201172, 924.92275]
# rho_vap: [101.822185, 98.072467]
# --- End ---
#
# T=274.00 K | evaluating at P_bubble=92.751616 bar, P_dew=38.604965 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 274.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [92.751616, 38.604965]
# gamma_Parachor_mN_m: [4.30851536, 4.22186423]
# gamma_WSD_mN_m: [4.82946107, 4.28152734]
# x: [[1.0, 0.0], [0.997291, 0.002709]]
# y: [[0.485038, 0.514962], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.89572698]
# M_vap: [22.38439857, 41.90969228]
# rho_liq: [965.742514, 918.651239]
# rho_vap: [103.469974, 101.26907]
# --- End ---
#
# T=275.00 K | evaluating at P_bubble=92.261689 bar, P_dew=39.665996 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 275.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [92.261689, 39.665996]
# gamma_Parachor_mN_m: [2.49195023, 4.03977731]
# gamma_WSD_mN_m: [3.23406821, 4.10024439]
# x: [[0.95, 0.05], [0.997128, 0.002872]]
# y: [[0.540948, 0.459052], [0.949997, 0.050003]]
# M_liq: [41.90983914, 43.88888849]
# M_vap: [24.73223636, 41.90969356]
# rho_liq: [851.116424, 912.252747]
# rho_vap: [118.501004, 104.580833]
# --- End ---
#
# T=276.00 K | evaluating at P_bubble=91.827279 bar, P_dew=40.750396 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 276.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [91.827279, 40.750396]
# gamma_Parachor_mN_m: [2.37914419, 3.85926928]
# gamma_WSD_mN_m: [3.08410971, 3.92052168]
# x: [[0.95, 0.05], [0.996955, 0.003045]]
# y: [[0.556148, 0.443852], [0.949997, 0.050003]]
# M_liq: [41.90983917, 43.88161001]
# M_vap: [25.37055903, 41.9096948]
# rho_liq: [844.529193, 905.719814]
# rho_vap: [121.887132, 108.014171]
# --- End ---
#
# T=277.00 K | evaluating at P_bubble=91.446851 bar, P_dew=41.858728 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 277.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [91.446851, 41.858728]
# gamma_Parachor_mN_m: [2.26629767, 3.68039047]
# gamma_WSD_mN_m: [2.93560292, 3.74240601]
# x: [[0.950001, 0.049999], [0.99677, 0.00323]]
# y: [[0.571408, 0.428592], [0.949997, 0.050003]]
# M_liq: [41.90984256, 43.8738562]
# M_vap: [26.01138029, 41.90969601]
# rho_liq: [837.81428, 899.044288]
# rho_vap: [125.44313, 111.576095]
# --- End ---
#
# T=278.00 K | evaluating at P_bubble=91.119321 bar, P_dew=42.991590 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 278.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [91.119321, 42.99159]
# gamma_Parachor_mN_m: [2.1535536, 3.50319506]
# gamma_WSD_mN_m: [2.78861745, 3.5659475]
# x: [[0.950001, 0.049999], [0.996573, 0.003427]]
# y: [[0.586697, 0.413303], [0.949997, 0.050003]]
# M_liq: [41.90984236, 43.86558778]
# M_vap: [26.65342242, 41.90969715]
# rho_liq: [830.96368, 892.217232]
# rho_vap: [129.17743, 115.274294]
# --- End ---
#
# T=279.00 K | evaluating at P_bubble=90.843188 bar, P_dew=44.149622 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 279.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [90.843188, 44.149622]
# gamma_Parachor_mN_m: [0.563661, 3.32774158]
# gamma_WSD_mN_m: [1.56216723, 3.3912]
# x: [[1.0, 0.0], [0.996363, 0.003637]]
# y: [[0.838457, 0.161543], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.85676093]
# M_vap: [37.22570422, 41.9096982]
# rho_liq: [937.480088, 885.228818]
# rho_vap: [422.053918, 119.117223]
# --- End ---
#
# T=280.00 K | evaluating at P_bubble=90.617111 bar, P_dew=45.333507 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 280.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [90.617111, 45.333507]
# gamma_Parachor_mN_m: [0.50771969, 3.15408932]
# gamma_WSD_mN_m: [1.44457544, 3.21821939]
# x: [[1.0, 0.0], [0.996138, 0.003862]]
# y: [[0.844415, 0.155585], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.84732655]
# M_vap: [37.47591758, 41.90970251]
# rho_liq: [931.613737, 878.068185]
# rho_vap: [430.294373, 123.11447]
# --- End ---
#
# T=281.00 K | evaluating at P_bubble=90.439732 bar, P_dew=46.543981 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 281.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [90.439732, 46.543981]
# gamma_Parachor_mN_m: [1.81758232, 2.98231422]
# gamma_WSD_mN_m: [2.35764564, 3.04707207]
# x: [[0.950001, 0.049999], [0.995898, 0.004102]]
# y: [[0.632426, 0.367574], [0.949997, 0.050003]]
# M_liq: [41.90984362, 43.83722938]
# M_vap: [28.57374111, 41.90970412]
# rho_liq: [809.507288, 870.723289]
# rho_vap: [141.536828, 127.275954]
# --- End ---
#
# T=282.00 K | evaluating at P_bubble=90.309665 bar, P_dew=47.781843 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 282.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [90.309665, 47.781843]
# gamma_Parachor_mN_m: [1.70693306, 2.81248793]
# gamma_WSD_mN_m: [2.21763567, 2.87782417]
# x: [[0.950001, 0.049999], [0.99564, 0.00436]]
# y: [[0.647516, 0.352484], [0.949997, 0.050003]]
# M_liq: [41.90984356, 43.82640696]
# M_vap: [29.20743274, 41.90970572]
# rho_liq: [802.018434, 863.180703]
# rho_vap: [146.073845, 131.613395]
# --- End ---
#
# T=283.00 K | evaluating at P_bubble=90.225477 bar, P_dew=49.047956 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 283.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [90.225477, 49.047956]
# gamma_Parachor_mN_m: [1.59726905, 2.64469237]
# gamma_WSD_mN_m: [2.07962658, 2.71054947]
# x: [[0.950001, 0.049999], [0.995363, 0.004637]]
# y: [[0.662478, 0.337522], [0.949997, 0.050003]]
# M_liq: [41.90984357, 43.81478831]
# M_vap: [29.8357445, 41.90970731]
# rho_liq: [794.340649, 855.425381]
# rho_vap: [150.837269, 136.13968]
# --- End ---
#
# T=284.00 K | evaluating at P_bubble=90.185673 bar, P_dew=50.343268 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 284.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [90.185673, 50.343268]
# gamma_Parachor_mN_m: [1.48879027, 2.47901748]
# gamma_WSD_mN_m: [1.94373466, 2.54532844]
# x: [[0.950001, 0.049999], [0.995066, 0.004934]]
# y: [[0.677284, 0.322716], [0.949997, 0.050003]]
# M_liq: [41.90984364, 43.80229232]
# M_vap: [30.45746809, 41.90970886]
# rho_liq: [786.459304, 847.440367]
# rho_vap: [155.8394, 140.869289]
# --- End ---
#
# T=285.00 K | evaluating at P_bubble=90.188677 bar, P_dew=51.668818 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 285.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [90.188677, 51.668818]
# gamma_Parachor_mN_m: [1.38170313, 2.31556245]
# gamma_WSD_mN_m: [1.81008253, 2.38224926]
# x: [[0.950001, 0.049999], [0.994745, 0.005255]]
# y: [[0.691906, 0.308094], [0.949997, 0.050003]]
# M_liq: [41.90984379, 43.78882571]
# M_vap: [31.07149977, 41.9097103]
# rho_liq: [778.357847, 839.206429]
# rho_vap: [161.094088, 145.818589]
# --- End ---
#
# T=286.00 K | evaluating at P_bubble=90.232664 bar, P_dew=53.025759 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 286.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [90.232664, 53.025759]
# gamma_Parachor_mN_m: [1.27622258, 2.1544371]
# gamma_WSD_mN_m: [1.67880088, 2.22140894]
# x: [[0.950001, 0.049999], [0.994399, 0.005601]]
# y: [[0.706322, 0.293678], [0.949997, 0.050003]]
# M_liq: [41.90984888, 43.77428048]
# M_vap: [31.67687861, 41.90971155]
# rho_liq: [770.017479, 830.7016]
# rho_vap: [166.616942, 151.006183]
# --- End ---
#
# T=287.00 K | evaluating at P_bubble=90.316153 bar, P_dew=54.415375 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 287.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [90.316153, 54.415375]
# gamma_Parachor_mN_m: [1.17256054, 1.99576376]
# gamma_WSD_mN_m: [1.55002143, 2.06291477]
# x: [[0.950001, 0.049999], [0.994024, 0.005976]]
# y: [[0.720511, 0.279489], [0.949997, 0.050003]]
# M_liq: [41.90984858, 43.75853065]
# M_vap: [32.27275856, 41.90971245]
# rho_liq: [761.41644, 821.900587]
# rho_vap: [172.426846, 156.453358]
# --- End ---
#
# T=288.00 K | evaluating at P_bubble=90.437022 bar, P_dew=55.839111 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 288.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [90.437022, 55.839111]
# gamma_Parachor_mN_m: [1.07094387, 1.83967942]
# gamma_WSD_mN_m: [1.42388929, 1.90688603]
# x: [[0.950001, 0.049999], [0.993616, 0.006384]]
# y: [[0.73446, 0.26554], [0.949997, 0.050003]]
# M_liq: [41.90984944, 43.74142799]
# M_vap: [32.85851307, 41.90971272]
# rho_liq: [752.529843, 812.774012]
# rho_vap: [178.545258, 162.184653]
# --- End ---
#
# T=289.00 K | evaluating at P_bubble=90.593141 bar, P_dew=57.298605 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 289.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [90.593141, 57.298605]
# gamma_Parachor_mN_m: [0.9716034, 1.68633174]
# gamma_WSD_mN_m: [1.30055645, 1.75345254]
# x: [[0.950001, 0.049999], [0.993173, 0.006827]]
# y: [[0.748156, 0.251844], [0.949998, 0.050002]]
# M_liq: [41.90984923, 43.72279648]
# M_vap: [33.43366763, 41.90971913]
# rho_liq: [743.32836, 803.287421]
# rho_vap: [184.997712, 168.229246]
# --- End ---
#
# T=290.00 K | evaluating at P_bubble=90.782156 bar, P_dew=58.795736 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 290.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [90.782156, 58.795736]
# gamma_Parachor_mN_m: [0.87477823, 1.53590646]
# gamma_WSD_mN_m: [1.18018572, 1.6027702]
# x: [[0.950001, 0.049999], [0.992688, 0.007312]]
# y: [[0.761594, 0.238406], [0.949998, 0.050002]]
# M_liq: [41.90984915, 43.70242487]
# M_vap: [33.99796857, 41.9097206]
# rho_liq: [733.777734, 793.399962]
# rho_vap: [191.815218, 174.619654]
# --- End ---
#
# T=291.00 K | evaluating at P_bubble=91.001430 bar, P_dew=60.332683 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 291.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [91.00143, 60.332683]
# gamma_Parachor_mN_m: [0.78071897, 1.3885998]
# gamma_WSD_mN_m: [1.06295385, 1.45500726]
# x: [[0.950001, 0.049999], [0.992155, 0.007845]]
# y: [[0.774772, 0.225228], [0.949998, 0.050002]]
# M_liq: [41.9098492, 43.68005652]
# M_vap: [34.55136358, 41.90972139]
# rho_liq: [723.837158, 783.062625]
# rho_vap: [199.035311, 181.39601]
# --- End ---
#
# T=292.00 K | evaluating at P_bubble=91.247964 bar, P_dew=61.912004 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 292.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [91.247964, 61.912004]
# gamma_Parachor_mN_m: [0.68969142, 1.24464446]
# gamma_WSD_mN_m: [0.94905551, 1.31035974]
# x: [[0.950001, 0.049999], [0.991567, 0.008433]]
# y: [[0.787694, 0.212306], [0.949998, 0.050002]]
# M_liq: [41.90984939, 43.65537549]
# M_vap: [35.09402074, 41.90972069]
# rho_liq: [713.457561, 772.215848]
# rho_vap: [206.704063, 188.605946]
# --- End ---
#
# T=293.00 K | evaluating at P_bubble=91.518264 bar, P_dew=63.536749 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 293.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [91.518264, 63.536749]
# gamma_Parachor_mN_m: [0.21203855, 1.10430506]
# gamma_WSD_mN_m: [0.56095289, 1.16905068]
# x: [[1.0, 0.0], [0.990915, 0.009085]]
# y: [[0.901389, 0.098611], [0.949998, 0.050002]]
# M_liq: [44.0095, 43.62798672]
# M_vap: [39.8684655, 41.90972811]
# rho_liq: [846.43791, 760.786249]
# rho_vap: [459.388425, 196.308511]
# --- End ---
#
# T=294.00 K | evaluating at P_bubble=91.808190 bar, P_dew=65.210619 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 294.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [91.80819, 65.210619]
# gamma_Parachor_mN_m: [0.51790075, 0.96791854]
# gamma_WSD_mN_m: [0.73215919, 1.0313546]
# x: [[0.950001, 0.049999], [0.990186, 0.009814]]
# y: [[0.812817, 0.187183], [0.949998, 0.050002]]
# M_liq: [41.90985199, 43.59738744]
# M_vap: [36.14901013, 41.90972784]
# rho_liq: [691.127473, 748.682097]
# rho_vap: [223.631386, 204.573951]
# --- End ---
#
# T=295.00 K | evaluating at P_bubble=92.112623 bar, P_dew=66.938197 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 295.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [92.112623, 66.938197]
# gamma_Parachor_mN_m: [0.1937431, 0.83586694]
# gamma_WSD_mN_m: [0.47211294, 0.89758611]
# x: [[1.0, 0.0], [0.989366, 0.010634]]
# y: [[0.90823, 0.09177], [0.949998, 0.050002]]
# M_liq: [44.0095, 43.56292468]
# M_vap: [40.15574444, 41.9097343]
# rho_liq: [831.276724, 735.786972]
# rho_vap: [456.499825, 213.494324]
# --- End ---
#
# T=296.00 K | evaluating at P_bubble=92.424968 bar, P_dew=68.725299 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 296.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [92.424968, 68.725299]
# gamma_Parachor_mN_m: [0.36204333, 0.70864578]
# gamma_WSD_mN_m: [0.53163665, 0.76814227]
# x: [[0.950001, 0.049999], [0.988432, 0.011568]]
# y: [[0.837122, 0.162878], [0.949998, 0.050002]]
# M_liq: [41.90985363, 43.5237298]
# M_vap: [37.16966086, 41.90973215]
# rho_liq: [666.096934, 721.950637]
# rho_vap: [243.268774, 223.1848]
# --- End ---
#
# T=297.00 K | evaluating at P_bubble=92.736354 bar, P_dew=70.579533 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 297.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [92.736354, 70.579533]
# gamma_Parachor_mN_m: [0.29108992, 0.58685344]
# gamma_WSD_mN_m: [0.43838727, 0.64350416]
# x: [[0.950001, 0.049999], [0.987358, 0.012642]]
# y: [[0.849059, 0.150941], [0.949998, 0.050002]]
# M_liq: [41.9098553, 43.47861345]
# M_vap: [37.67093714, 41.90973842]
# rho_liq: [652.225985, 706.975286]
# rho_vap: [254.436317, 233.802189]
# --- End ---
#
# T=298.00 K | evaluating at P_bubble=93.034403 bar, P_dew=72.511275 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 298.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [93.034403, 72.511275]
# gamma_Parachor_mN_m: [0.22544932, 0.47128371]
# gamma_WSD_mN_m: [0.35042623, 0.52429998]
# x: [[0.950001, 0.049999], [0.986102, 0.013898]]
# y: [[0.86093, 0.13907], [0.949997, 0.050003]]
# M_liq: [41.90985612, 43.42588351]
# M_vap: [38.16944726, 41.90971043]
# rho_liq: [637.158149, 690.592986]
# rho_vap: [266.780435, 245.555614]
# --- End ---
#
# T=299.00 K | evaluating at P_bubble=93.301511 bar, P_dew=74.535166 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 299.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [93.301511, 74.535166]
# gamma_Parachor_mN_m: [1.71760905, 0.36292628]
# gamma_WSD_mN_m: [1.00863642, 0.41132429]
# x: [[1.0, 0.0], [0.984605, 0.015395]]
# y: [[0.711591, 0.288409], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.36302908]
# M_vap: [31.8981504, 41.90969303]
# rho_liq: [797.98424, 672.425686]
# rho_vap: [157.862692, 258.753988]
# --- End ---
#
# T=300.00 K | evaluating at P_bubble=93.512978 bar, P_dew=76.673402 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 300.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [93.512978, 76.673402]
# gamma_Parachor_mN_m: [1.64578944, 0.2631172]
# gamma_WSD_mN_m: [0.86626177, 0.30565673]
# x: [[1.0, 0.0], [0.982773, 0.017227]]
# y: [[0.719578, 0.280422], [0.949997, 0.050003]]
# M_liq: [44.0095, 43.2860631]
# M_vap: [32.23358598, 41.90970295]
# rho_liq: [788.721256, 651.906403]
# rho_vap: [160.38621, 273.863464]
# --- End ---
#
# T=301.00 K | evaluating at P_bubble=93.634838 bar, P_dew=78.962674 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 301.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [93.634838, 78.962674]
# gamma_Parachor_mN_m: [1.58391999, 0.17377448]
# gamma_WSD_mN_m: [0.71966526, 0.20886796]
# x: [[1.0, 0.0], [0.98044, 0.01956]]
# y: [[0.727962, 0.272038], [0.949996, 0.050004]]
# M_liq: [44.0095, 43.1880972]
# M_vap: [32.58565183, 41.9096336]
# rho_liq: [778.857318, 628.125762]
# rho_vap: [162.911044, 291.640005]
# --- End ---
#
# T=302.00 K | evaluating at P_bubble=93.617949 bar, P_dew=81.471287 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 302.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [93.617949, 81.471287]
# gamma_Parachor_mN_m: [1.54361468, 0.09780187]
# gamma_WSD_mN_m: [0.56533696, 0.12342567]
# x: [[1.0, 0.0], [0.977292, 0.022708]]
# y: [[0.73701, 0.26299], [0.949996, 0.050004]]
# M_liq: [44.0095, 43.05590139]
# M_vap: [32.96560629, 41.90963685]
# rho_liq: [768.166722, 599.549376]
# rho_vap: [165.439277, 313.531196]
# --- End ---
#
# T=303.00 K | evaluating at P_bubble=93.346208 bar, P_dew=84.360074 bar
# Given temperature is greater than Tc (33.145) for Hydrogen
# Computing interfacial tension at T = 0.9*33.145 for Parachor method
#
# --- Results ---
# Temperature           : 303.0000 K
# Critical Temperature  : 304.1282 K
# Pbar: [93.346208, 84.360074]
# gamma_Parachor_mN_m: [1.5803733, 0.03991787]
# gamma_WSD_mN_m: [0.39590619, 0.05368786]
# x: [[1.0, 0.0], [0.972594, 0.027406]]
# y: [[0.747377, 0.252623], [0.949981, 0.050019]]
# M_liq: [44.0095, 42.85860734]
# M_vap: [33.40096466, 41.90901113]
# rho_liq: [756.154339, 563.245959]
# rho_vap: [167.976926, 342.761859]
# --- End ---

# %%
# --- choose which surface tension to use for SHL ---
GAMMA_KEY = "gamma_Parachor_mN_m"  # or "gamma_WSD_mN_m"

# --- choose which side to compute ---
SIDE = "dew"      # "bubble", "dew", or "both"
# -----------------------------------

def collect_shl_points(results_all, side):
    points = []
    for rec in results_all:
        T_K = rec["T_K"]
        keyed = {s["point_type"]: s for s in rec["samples"]}

        s = keyed.get(side)
        if s is None:
            print(f"[skip] T={T_K:.2f} K | missing {side} sample")
            continue

        Psat_Pa   = s["P_bar"] * 1e5
        gamma_N_m = s[GAMMA_KEY] * 1e-3
        rho_L     = s["rho_liq_kg_per_m3"]
        x_list    = s["x"]

        # Basic sanity checks
        if gamma_N_m <= 0.0:
            print(f"[skip] T={T_K:.2f} K, {side:5s} | gamma<=0 from {GAMMA_KEY} (γ={gamma_N_m:.3e} N/m) — near Tc?")
            continue
        if rho_L <= 0.0:
            print(f"[skip] T={T_K:.2f} K, {side:5s} | rho_L invalid ({rho_L:g})")
            continue
        if abs(sum(x_list) - 1.0) > 1e-8:
            print(f"[skip] T={T_K:.2f} K, {side:5s} | x does not sum to 1 (sum={sum(x_list):.6f})")
            continue

        points.append({
            "T_K": T_K,
            "Psat_Pa": Psat_Pa,
            "gamma_N_m": gamma_N_m,
            "rho_L": rho_L,
            "x_list": x_list,
            "meta": {"point_type": side, "P_bar": s["P_bar"], "y_list": s["y"]},
        })
    return points

# --- run SHL only on valid points; skip those failing CNT conditions ---
M_CO2, M_H2 = 44.00985e-3, 2.01588e-3
M_list = [M_CO2, M_H2]
Jcrit = 1e12

def run_shl(points, label):
    results = []
    for row in points:
        try:
            shl = SHLMixture(
                Jcrit=Jcrit,
                Psat=row["Psat_Pa"],
                T=row["T_K"],
                gamma=row["gamma_N_m"],
                rho_L=row["rho_L"],
                M_list=M_list,
                x_list=row["x_list"],
            )
            DeltaP, Pc, rc = shl.compute()
            results.append({"T_K": row["T_K"], "Pc_bar": Pc/1e5, "DeltaP_Pa": DeltaP, "rc_m": rc})
        except ValueError as e:
            print(f"[skip] T={row['T_K']:.2f} K, {label:5s} | {e}")
            continue
    return results

if SIDE in ("bubble", "dew"):
    shl_points   = collect_shl_points(results_all, SIDE)
    shl_results  = run_shl(shl_points, SIDE)
    csv_filename = f"SHL_CO2_H2_{SIDE}.csv"

    with open(csv_filename, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["T_K", "Pc_bar"])
        for r in shl_results:
            print(f"T={r['T_K']:.2f} K | SHL {SIDE} Pc = {r['Pc_bar']:.3f} bar")
            writer.writerow([r["T_K"], r["Pc_bar"]])

elif SIDE == "both":
    for side in ("bubble", "dew"):
        shl_points  = collect_shl_points(results_all, side)
        shl_results = run_shl(shl_points, side)
        csv_filename = f"SHL_CO2_H2_{side}.csv"

        with open(csv_filename, "w", newline="") as f:
            writer = csv.writer(f)
            writer.writerow(["T_K", "Pc_bar"])
            for r in shl_results:
                print(f"T={r['T_K']:.2f} K | SHL {side} Pc = {r['Pc_bar']:.3f} bar")
                writer.writerow([r["T_K"], r["Pc_bar"]])
else:
    raise ValueError("SIDE must be 'bubble', 'dew', or 'both'.")
# Out:
# [skip] T=220.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=221.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# [skip] T=222.00 K, dew   | gamma<=0 from gamma_Parachor_mN_m (γ=0.000e+00 N/m) — near Tc?
# T=223.00 K | SHL dew Pc = -162.043 bar
# T=224.00 K | SHL dew Pc = -157.468 bar
# T=225.00 K | SHL dew Pc = -152.945 bar
# T=226.00 K | SHL dew Pc = -148.474 bar
# T=227.00 K | SHL dew Pc = -144.054 bar
# T=228.00 K | SHL dew Pc = -139.685 bar
# T=229.00 K | SHL dew Pc = -135.366 bar
# T=230.00 K | SHL dew Pc = -131.097 bar
# T=231.00 K | SHL dew Pc = -126.876 bar
# T=232.00 K | SHL dew Pc = -122.704 bar
# T=233.00 K | SHL dew Pc = -118.580 bar
# T=234.00 K | SHL dew Pc = -114.502 bar
# T=235.00 K | SHL dew Pc = -110.472 bar
# T=236.00 K | SHL dew Pc = -106.488 bar
# T=237.00 K | SHL dew Pc = -102.549 bar
# T=238.00 K | SHL dew Pc = -98.656 bar
# T=239.00 K | SHL dew Pc = -94.807 bar
# T=240.00 K | SHL dew Pc = -91.002 bar
# T=241.00 K | SHL dew Pc = -87.241 bar
# T=242.00 K | SHL dew Pc = -83.523 bar
# T=243.00 K | SHL dew Pc = -79.848 bar
# T=244.00 K | SHL dew Pc = -76.214 bar
# T=245.00 K | SHL dew Pc = -72.622 bar
# T=246.00 K | SHL dew Pc = -69.071 bar
# T=247.00 K | SHL dew Pc = -65.561 bar
# T=248.00 K | SHL dew Pc = -62.091 bar
# T=249.00 K | SHL dew Pc = -58.660 bar
# T=250.00 K | SHL dew Pc = -55.268 bar
# T=251.00 K | SHL dew Pc = -51.915 bar
# T=252.00 K | SHL dew Pc = -48.601 bar
# T=253.00 K | SHL dew Pc = -45.324 bar
# T=254.00 K | SHL dew Pc = -42.084 bar
# T=255.00 K | SHL dew Pc = -38.881 bar
# T=256.00 K | SHL dew Pc = -35.714 bar
# T=257.00 K | SHL dew Pc = -32.583 bar
# T=258.00 K | SHL dew Pc = -29.487 bar
# T=259.00 K | SHL dew Pc = -26.426 bar
# T=260.00 K | SHL dew Pc = -23.400 bar
# T=261.00 K | SHL dew Pc = -20.408 bar
# T=262.00 K | SHL dew Pc = -17.449 bar
# T=263.00 K | SHL dew Pc = -14.523 bar
# T=264.00 K | SHL dew Pc = -11.629 bar
# T=265.00 K | SHL dew Pc = -8.768 bar
# T=266.00 K | SHL dew Pc = -5.939 bar
# T=267.00 K | SHL dew Pc = -3.140 bar
# T=268.00 K | SHL dew Pc = -0.373 bar
# T=269.00 K | SHL dew Pc = 2.365 bar
# T=270.00 K | SHL dew Pc = 5.072 bar
# T=271.00 K | SHL dew Pc = 7.751 bar
# T=272.00 K | SHL dew Pc = 10.400 bar
# T=273.00 K | SHL dew Pc = 13.022 bar
# T=274.00 K | SHL dew Pc = 15.615 bar
# T=275.00 K | SHL dew Pc = 18.182 bar
# T=276.00 K | SHL dew Pc = 20.722 bar
# T=277.00 K | SHL dew Pc = 23.236 bar
# T=278.00 K | SHL dew Pc = 25.724 bar
# T=279.00 K | SHL dew Pc = 28.187 bar
# T=280.00 K | SHL dew Pc = 30.627 bar
# T=281.00 K | SHL dew Pc = 33.042 bar
# T=282.00 K | SHL dew Pc = 35.435 bar
# T=283.00 K | SHL dew Pc = 37.806 bar
# T=284.00 K | SHL dew Pc = 40.156 bar
# T=285.00 K | SHL dew Pc = 42.485 bar
# T=286.00 K | SHL dew Pc = 44.795 bar
# T=287.00 K | SHL dew Pc = 47.087 bar
# T=288.00 K | SHL dew Pc = 49.362 bar
# T=289.00 K | SHL dew Pc = 51.622 bar
# T=290.00 K | SHL dew Pc = 53.868 bar
# T=291.00 K | SHL dew Pc = 56.101 bar
# T=292.00 K | SHL dew Pc = 58.326 bar
# T=293.00 K | SHL dew Pc = 60.543 bar
# T=294.00 K | SHL dew Pc = 62.757 bar
# T=295.00 K | SHL dew Pc = 64.971 bar
# T=296.00 K | SHL dew Pc = 67.191 bar
# T=297.00 K | SHL dew Pc = 69.424 bar
# T=298.00 K | SHL dew Pc = 71.680 bar
# T=299.00 K | SHL dew Pc = 73.974 bar
# T=300.00 K | SHL dew Pc = 76.327 bar
# T=301.00 K | SHL dew Pc = 78.777 bar
# T=302.00 K | SHL dew Pc = 81.393 bar
# T=303.00 K | SHL dew Pc = 84.340 bar

# %%
# --- choose which surface tension to use ---
GAMMA_KEY = "gamma_Parachor_mN_m"  # or "gamma_WSD_mN_m"

# --- choose which side to compute ---
SIDE = "bubble"      # <<< change to "bubble" or "dew" here
# --------------------------------------

scl_points = []

for rec in results_all:
    T_K = rec["T_K"]
    keyed = {s["point_type"]: s for s in rec["samples"]}

    # pick only the chosen side
    s = keyed.get(SIDE)
    if s is None:
        print(f"[skip] T={T_K:.2f} K | missing {SIDE} sample")
        continue

    # Extract needed fields
    Psat_Pa   = s["P_bar"] * 1e5
    gamma_N_m = s[GAMMA_KEY] * 1e-3
    rho_L     = s["rho_liq_kg_per_m3"]
    rho_g     = s["rho_vap_kg_per_m3"]
    x_list    = s["x"]
    y_list    = s["y"]

    # Sanity checks
    if gamma_N_m <= 0.0:
        print(f"[skip] T={T_K:.2f} K | gamma<=0 ({gamma_N_m:.3e})")
        continue
    if rho_L <= 0.0 or rho_g <= 0.0:
        print(f"[skip] T={T_K:.2f} K | invalid densities")
        continue
    if abs(sum(x_list) - 1.0) > 1e-8 or abs(sum(y_list) - 1.0) > 1e-8:
        print(f"[skip] T={T_K:.2f} K | composition sum error")
        continue

    scl_points.append({
        "T_K": T_K,
        "Psat_Pa": Psat_Pa,
        "gamma_N_m": gamma_N_m,
        "rho_L": rho_L,
        "rho_g": rho_g,
        "x_list": x_list,
        "y_list": y_list,
        "meta": {"point_type": SIDE, "P_bar": s["P_bar"]},
    })

# --- constants ---
M_CO2, M_H2 = 44.00985e-3, 2.01588e-3
M_list = [M_CO2, M_H2]
Jcrit = 1e12

# --- run SCL ---
def run_scl(points, label):
    results = []
    for row in points:
        try:
            scl = SCLMixture(
                Jcrit=Jcrit,
                Psat=row["Psat_Pa"],
                T=row["T_K"],
                gamma=row["gamma_N_m"],
                rho_L=row["rho_L"],
                rho_g=row["rho_g"],
                M_list=M_list,
                x_list=row["x_list"],
                y_list=row["y_list"],
            )
            Pc, rc, lnS = scl.compute()
            results.append({"T_K": row["T_K"], "Pc_bar": Pc/1e5, "rc_m": rc, "lnS": lnS})
        except ValueError as e:
            print(f"[skip] T={row['T_K']:.2f} K, {label:5s} | {e}")
            continue
    return results

scl_results = run_scl(scl_points, SIDE)

# --- save results ---
import csv
csv_filename = f"SCL_CO2_H2_{SIDE}.csv"

with open(csv_filename, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["T_K", "Pc_bar"])  # header row
    for r in scl_results:
        print(f"T={r['T_K']:.2f} K | SCL {SIDE} Pc = {r['Pc_bar']:.3f} bar")
        writer.writerow([r["T_K"], r["Pc_bar"]])
# Out:
# [skip] T=220.00 K | gamma<=0 (0.000e+00)
# [skip] T=221.00 K | gamma<=0 (0.000e+00)
# [skip] T=222.00 K | gamma<=0 (0.000e+00)
# T=223.00 K | SCL bubble Pc = 458.992 bar
# T=224.00 K | SCL bubble Pc = 396.875 bar
# T=225.00 K | SCL bubble Pc = 361.453 bar
# T=226.00 K | SCL bubble Pc = 335.263 bar
# T=227.00 K | SCL bubble Pc = 314.168 bar
# T=228.00 K | SCL bubble Pc = 296.415 bar
# T=229.00 K | SCL bubble Pc = 281.052 bar
# T=230.00 K | SCL bubble Pc = 267.500 bar
# T=231.00 K | SCL bubble Pc = 255.388 bar
# T=232.00 K | SCL bubble Pc = 244.447 bar
# T=233.00 K | SCL bubble Pc = 234.478 bar
# T=234.00 K | SCL bubble Pc = 225.343 bar
# T=235.00 K | SCL bubble Pc = 216.924 bar
# T=236.00 K | SCL bubble Pc = 209.131 bar
# T=237.00 K | SCL bubble Pc = 201.890 bar
# T=238.00 K | SCL bubble Pc = 195.139 bar
# T=239.00 K | SCL bubble Pc = 188.833 bar
# T=240.00 K | SCL bubble Pc = 182.926 bar
# T=241.00 K | SCL bubble Pc = 177.382 bar
# T=242.00 K | SCL bubble Pc = 172.171 bar
# T=243.00 K | SCL bubble Pc = 167.263 bar
# T=244.00 K | SCL bubble Pc = 162.638 bar
# T=245.00 K | SCL bubble Pc = 158.273 bar
# T=246.00 K | SCL bubble Pc = 154.150 bar
# T=247.00 K | SCL bubble Pc = 150.252 bar
# T=248.00 K | SCL bubble Pc = 146.563 bar
# T=249.00 K | SCL bubble Pc = 143.073 bar
# T=250.00 K | SCL bubble Pc = 139.768 bar
# T=251.00 K | SCL bubble Pc = 136.637 bar
# T=252.00 K | SCL bubble Pc = 133.670 bar
# T=253.00 K | SCL bubble Pc = 130.858 bar
# T=254.00 K | SCL bubble Pc = 128.193 bar
# T=255.00 K | SCL bubble Pc = 125.667 bar
# T=256.00 K | SCL bubble Pc = 123.273 bar
# T=257.00 K | SCL bubble Pc = 121.005 bar
# T=258.00 K | SCL bubble Pc = 118.857 bar
# T=259.00 K | SCL bubble Pc = 116.823 bar
# T=260.00 K | SCL bubble Pc = 114.899 bar
# T=261.00 K | SCL bubble Pc = 113.079 bar
# T=262.00 K | SCL bubble Pc = 111.359 bar
# T=263.00 K | SCL bubble Pc = 109.736 bar
# T=264.00 K | SCL bubble Pc = 108.205 bar
# T=265.00 K | SCL bubble Pc = 106.763 bar
# T=266.00 K | SCL bubble Pc = 105.407 bar
# T=267.00 K | SCL bubble Pc = 104.134 bar
# T=268.00 K | SCL bubble Pc = 102.941 bar
# T=269.00 K | SCL bubble Pc = 101.826 bar
# T=270.00 K | SCL bubble Pc = 100.785 bar
# T=271.00 K | SCL bubble Pc = 99.818 bar
# T=272.00 K | SCL bubble Pc = 98.920 bar
# T=273.00 K | SCL bubble Pc = 98.092 bar
# T=274.00 K | SCL bubble Pc = 97.330 bar
# T=275.00 K | SCL bubble Pc = 94.391 bar
# T=276.00 K | SCL bubble Pc = 93.808 bar
# T=277.00 K | SCL bubble Pc = 93.284 bar
# T=278.00 K | SCL bubble Pc = 92.819 bar
# T=279.00 K | SCL bubble Pc = 91.051 bar
# T=280.00 K | SCL bubble Pc = 90.794 bar
# T=281.00 K | SCL bubble Pc = 91.759 bar
# T=282.00 K | SCL bubble Pc = 91.513 bar
# T=283.00 K | SCL bubble Pc = 91.318 bar
# T=284.00 K | SCL bubble Pc = 91.173 bar
# T=285.00 K | SCL bubble Pc = 91.075 bar
# T=286.00 K | SCL bubble Pc = 91.024 bar
# T=287.00 K | SCL bubble Pc = 91.018 bar
# T=288.00 K | SCL bubble Pc = 91.054 bar
# T=289.00 K | SCL bubble Pc = 91.131 bar
# T=290.00 K | SCL bubble Pc = 91.246 bar
# T=291.00 K | SCL bubble Pc = 91.397 bar
# T=292.00 K | SCL bubble Pc = 91.580 bar
# T=293.00 K | SCL bubble Pc = 91.568 bar
# T=294.00 K | SCL bubble Pc = 92.030 bar
# T=295.00 K | SCL bubble Pc = 92.157 bar
# T=296.00 K | SCL bubble Pc = 92.559 bar
# T=297.00 K | SCL bubble Pc = 92.835 bar
# T=298.00 K | SCL bubble Pc = 93.103 bar
# T=299.00 K | SCL bubble Pc = 94.515 bar
# T=300.00 K | SCL bubble Pc = 94.661 bar
# T=301.00 K | SCL bubble Pc = 94.729 bar
# T=302.00 K | SCL bubble Pc = 94.679 bar
# T=303.00 K | SCL bubble Pc = 94.455 bar
